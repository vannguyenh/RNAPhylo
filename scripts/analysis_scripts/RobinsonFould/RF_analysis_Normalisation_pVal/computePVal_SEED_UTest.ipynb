# %% [markdown]
# # Compute the median normalised RF distance of SEED dataset via taxa

# %%
#!/usr/bin/env python3
"""
Compute Mann–Whitney U-test p-values for normalised RF distances (SEED dataset).
Per-model FDR correction; output: long/wide CSVs + median normalised RF data.

Consolidated cell: processes all models, RNAs; generates CSV outputs; applies FDR.
"""

import os
import sys
import csv
import glob
import logging
from os.path import join, isdir, isfile, exists
from datetime import datetime
from collections import defaultdict

import numpy as np
import pandas as pd
from Bio import Phylo
from scipy.stats import mannwhitneyu
from statsmodels.stats.multitest import multipletests

# ─── PATHS ────────────────────────────────────────────────────────────────────
DIR_WORKING   = "/Users/u7875558/RNAPhylo/seedAlignment_AllModels"
DIR_OUTPUTS   = join(DIR_WORKING, "outputs")
DIR_TREES     = join(DIR_OUTPUTS, "inferred_trees")
DIR_DNA       = join(DIR_TREES, "DNA")
DIR_RF        = join(DIR_OUTPUTS, "251121_Robinson_Foulds")
DIR_DNA_extra = join(DIR_RF, "DNA_extra")
LOG_DIR       = join(DIR_OUTPUTS, "logs", "RF_distance")

os.makedirs(LOG_DIR, exist_ok=True)

# ─── LOGGING ──────────────────────────────────────────────────────────────────
log_file = join(LOG_DIR, f"computePVal_SEED_UTest_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log")
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[logging.FileHandler(log_file), logging.StreamHandler()]
)
logger = logging.getLogger(__name__)

# ─── CONSTANTS ────────────────────────────────────────────────────────────────
ALPHA = 0.05
DO_FDR = True
DO_BONFERRONI = False

# ─── HELPER FUNCTIONS ─────────────────────────────────────────────────────────
def choose_first_existing(pattern_list):
    """Return first existing file/dir from list of candidate paths."""
    for p in pattern_list:
        if exists(p):
            return p
    return None

def read_rfdist_matrix(path: str) -> np.ndarray:
    """Read IQ-TREE tab/space-separated distance matrix."""
    if not isfile(path):
        return np.array([])
    try:
        with open(path, 'r') as f:
            lines = f.readlines()
        rows = []
        for line in lines[1:]:  # skip header
            parts = line.strip().split()
            if len(parts) > 1:
                rows.append(list(map(float, parts[1:])))  # skip row label
        return np.array(rows, dtype=float) if rows else np.array([])
    except Exception as e:
        logger.warning(f"Error reading {path}: {e}")
        return np.array([])

def normalize_rf_matrix_by_n(mat: np.ndarray, n_taxa: int) -> np.ndarray:
    """Normalize RF distances: nRF = RF / (2*(n-3)) for unrooted binary trees."""
    if mat.size == 0 or n_taxa < 4:
        return np.array([])
    # Check if already normalized (max ≤ 1)
    if np.nanmax(mat) <= 1.0 + 1e-9:
        return mat.copy()
    denom = 2 * (n_taxa - 3)
    return mat / denom if denom > 0 else mat.copy()

def count_taxa(tree_path: str) -> int | None:
    """Count terminals in Newick tree."""
    try:
        with open(tree_path, 'r') as fh:
            tree = next(Phylo.parse(fh, 'newick'))
        return len(tree.get_terminals())
    except Exception as e:
        logger.debug(f"Error counting taxa in {tree_path}: {e}")
        return None

# ─── MAIN COMPUTATION ─────────────────────────────────────────────────────────
def process_one_rna(rna, model, model_rf_dir, dna_rf_dir, dna_taxa_dir):
    """
    Process one RNA × Model pair: read RF matrices, normalize, U-test.
    Returns: dict with test results, or None if skipped.
    """
    rna_model_rf = join(model_rf_dir, rna)
    rna_dna_rf = join(dna_rf_dir, rna)

    # Find RF distance files
    # For model: looking for .rfdist file (RF distance matrix)
    # NOTE: .dna and .rna files contain 10 concatenated Newick trees, NOT distance matrices
    model_rfdist = choose_first_existing([
        join(rna_model_rf, f"{rna}.rfdist"),
        join(rna_model_rf, f"{rna}.txt")
    ])
    # For DNA baseline: looking for .rfdist file (RF distance matrix)
    dna_rfdist = choose_first_existing([
        join(rna_dna_rf, f"{rna}.rfdist"),
        join(rna_dna_rf, f"{rna}.txt")
    ])

    if not model_rfdist or not dna_rfdist:
        logger.info(f"[SKIP {model}/{rna}] Missing RF distance files")
        return None

    # Read matrices
    mat_model = read_rfdist_matrix(model_rfdist)
    mat_dna = read_rfdist_matrix(dna_rfdist)

    if mat_model.size == 0 or mat_dna.size == 0:
        logger.info(f"[SKIP {model}/{rna}] Empty RF matrices")
        return None

    # Count taxa
    tree_pattern = join(dna_taxa_dir, rna, "RAxML_bestTree.*")
    tree_file = choose_first_existing([
        t for t in glob.glob(tree_pattern) if isfile(t)
    ])

    if not tree_file or not isfile(tree_file):
        logger.info(f"[SKIP {model}/{rna}] No tree found for taxa count")
        return None

    n_taxa = count_taxa(tree_file)
    if n_taxa is None or n_taxa < 4:
        logger.info(f"[SKIP {model}/{rna}] Invalid taxa count: {n_taxa}")
        return None

    # Normalize matrices
    mat_model_norm = normalize_rf_matrix_by_n(mat_model, n_taxa)
    mat_dna_norm = normalize_rf_matrix_by_n(mat_dna, n_taxa)

    if mat_model_norm.size == 0 or mat_dna_norm.size == 0:
        logger.info(f"[SKIP {model}/{rna}] Normalization failed")
        return None

    # Extract distance arrays (lower triangle)
    dna_vals = mat_dna_norm[np.tril_indices_from(mat_dna_norm, k=-1)]
    model_vals = mat_model_norm[np.tril_indices_from(mat_model_norm, k=-1)]

    if len(dna_vals) < 1 or len(model_vals) < 1:
        logger.info(f"[SKIP {model}/{rna}] Insufficient distance values")
        return None

    # Mann–Whitney U-test
    U, p_raw = mannwhitneyu(dna_vals, model_vals, alternative='two-sided')

    dna_median = np.median(dna_vals)
    model_median = np.median(model_vals)

    return {
        'RNA': rna,
        'Model': model,
        'Category': 'DNA vs extra DNA' if model == 'DNA_extra' else 'DNA vs RNA',
        'DNA_median': dna_median,
        'Model_median': model_median,
        'pvalue_raw': p_raw,
        'U_statistic': U,
        'n_dna_vals': len(dna_vals),
        'n_model_vals': len(model_vals),
        'n_taxa': n_taxa
    }

# Collect results per model
all_results = []
models = sorted([m for m in os.listdir(DIR_RF) if isdir(join(DIR_RF, m)) and m.startswith('S')])

for model in models:
    model_rf_dir = join(DIR_RF, model)
    rna_dirs = sorted(set(d for d in os.listdir(model_rf_dir) if isdir(join(model_rf_dir, d))))

    model_results = []
    for rna in rna_dirs:
        # Use DIR_DNA_extra as the DNA baseline
        res = process_one_rna(rna, model, model_rf_dir, DIR_DNA_extra, DIR_DNA)
        if res:
            model_results.append(res)

    # Per-model FDR correction
    if model_results and DO_FDR:
        pvals = np.array([r['pvalue_raw'] for r in model_results], dtype=float)
        reject, qvals, _, _ = multipletests(pvals, alpha=ALPHA, method='fdr_bh')
        for i, r in enumerate(model_results):
            r['q_value'] = qvals[i]
            r['sig_fdr'] = reject[i]

    all_results.extend(model_results)
    logger.info(f"Processed {model}: {len(model_results)} RNAs")

# Output dataframes
if all_results:
    df_long = pd.DataFrame(all_results)
    df_medians = df_long[['RNA', 'Model', 'Category', 'DNA_median', 'Model_median']].copy()
    df_medians.columns = ['RNA', 'Model', 'Category', 'DNA_nRF_median', 'Model_nRF_median']

    # Wide format
    df_wide = df_long.pivot_table(
        index='RNA',
        columns='Model',
        values=['DNA_median', 'Model_median', 'pvalue_raw', 'q_value'],
        aggfunc='first'
    )

    # Rename for clarity and export
    seed_long = df_long.copy()
    seed_medians = df_medians.copy()
    seed_medians['Median nRF'] = seed_medians['Model_nRF_median']
    seed_wide = df_wide

    # Save CSV files
    output_csv_long = join(DIR_OUTPUTS, 'SEED_Utest_all_models_long.csv')
    output_csv_wide = join(DIR_OUTPUTS, 'SEED_Utest_all_models_wide.csv')
    output_csv_medians = join(DIR_OUTPUTS, 'SEED_Median_nRF_all_models_long.csv')

    df_long.to_csv(output_csv_long, index=False)
    df_wide.to_csv(output_csv_wide)
    seed_medians.to_csv(output_csv_medians, index=False)

    logger.info(f"Saved: {output_csv_long} ({len(df_long)} rows)")
    logger.info(f"Saved: {output_csv_wide}")
    logger.info(f"Saved: {output_csv_medians} ({len(seed_medians)} rows)")

    print(f"\n✓ Completed: {len(all_results)} RNAs processed across {len(models)} models")
    print(f"✓ Output CSV files saved to {DIR_OUTPUTS}")
else:
    print(f"✗ ERROR: No results processed. Check data paths and RF distance files.")
# Out:
# 2025-12-02 11:25:18,492 - INFO - [SKIP S16/RF00207] Missing RF distance files
# 2025-12-02 11:25:25,528 - INFO - [SKIP S16/RF00976] Missing RF distance files
# 2025-12-02 11:25:25,528 - INFO - [SKIP S16/RF00976] Missing RF distance files
# 2025-12-02 11:25:26,138 - INFO - [SKIP S16/RF01047] Missing RF distance files
# 2025-12-02 11:25:26,138 - INFO - [SKIP S16/RF01047] Missing RF distance files
# 2025-12-02 11:25:28,638 - INFO - [SKIP S16/RF01338] Missing RF distance files
# 2025-12-02 11:25:28,638 - INFO - [SKIP S16/RF01338] Missing RF distance files
# 2025-12-02 11:25:28,670 - INFO - [SKIP S16/RF01380] Missing RF distance files
# 2025-12-02 11:25:28,670 - INFO - [SKIP S16/RF01380] Missing RF distance files
# 2025-12-02 11:25:43,212 - INFO - [SKIP S16/RF03623] Missing RF distance files
# 2025-12-02 11:25:43,212 - INFO - [SKIP S16/RF03623] Missing RF distance files
# 2025-12-02 11:25:43,506 - INFO - [SKIP S16/RF03760] Missing RF distance files
# 2025-12-02 11:25:43,506 - INFO - [SKIP S16/RF03760] Missing RF distance files
# 2025-12-02 11:25:43,845 - INFO - [SKIP S16/RF03969] Missing RF distance files
# 2025-12-02 11:25:43,845 - INFO - [SKIP S16/RF03969] Missing RF distance files
# 2025-12-02 11:25:45,646 - INFO - Processed S16: 1788 RNAs
# 2025-12-02 11:25:45,646 - INFO - Processed S16: 1788 RNAs
# 2025-12-02 11:25:46,523 - INFO - [SKIP S16A/RF00207] Missing RF distance files
# 2025-12-02 11:25:46,523 - INFO - [SKIP S16A/RF00207] Missing RF distance files
# 2025-12-02 11:25:49,794 - INFO - [SKIP S16A/RF00976] Missing RF distance files
# 2025-12-02 11:25:49,794 - INFO - [SKIP S16A/RF00976] Missing RF distance files
# 2025-12-02 11:25:50,051 - INFO - [SKIP S16A/RF01047] Missing RF distance files
# 2025-12-02 11:25:50,051 - INFO - [SKIP S16A/RF01047] Missing RF distance files
# 2025-12-02 11:25:50,729 - INFO - [SKIP S16A/RF01338] Missing RF distance files
# 2025-12-02 11:25:50,729 - INFO - [SKIP S16A/RF01338] Missing RF distance files
# 2025-12-02 11:25:50,740 - INFO - [SKIP S16A/RF01380] Missing RF distance files
# 2025-12-02 11:25:50,740 - INFO - [SKIP S16A/RF01380] Missing RF distance files
# 2025-12-02 11:25:55,469 - INFO - [SKIP S16A/RF03623] Missing RF distance files
# 2025-12-02 11:25:55,469 - INFO - [SKIP S16A/RF03623] Missing RF distance files
# 2025-12-02 11:25:55,560 - INFO - [SKIP S16A/RF03760] Missing RF distance files
# 2025-12-02 11:25:55,560 - INFO - [SKIP S16A/RF03760] Missing RF distance files
# 2025-12-02 11:25:55,670 - INFO - [SKIP S16A/RF03969] Missing RF distance files
# 2025-12-02 11:25:55,670 - INFO - [SKIP S16A/RF03969] Missing RF distance files
# 2025-12-02 11:25:56,328 - INFO - Processed S16A: 1788 RNAs
# 2025-12-02 11:25:56,328 - INFO - Processed S16A: 1788 RNAs
# 2025-12-02 11:25:57,103 - INFO - [SKIP S16B/RF00207] Missing RF distance files
# 2025-12-02 11:25:57,103 - INFO - [SKIP S16B/RF00207] Missing RF distance files
# 2025-12-02 11:25:59,738 - INFO - [SKIP S16B/RF00976] Missing RF distance files
# 2025-12-02 11:25:59,738 - INFO - [SKIP S16B/RF00976] Missing RF distance files
# 2025-12-02 11:25:59,905 - INFO - [SKIP S16B/RF01047] Missing RF distance files
# 2025-12-02 11:25:59,905 - INFO - [SKIP S16B/RF01047] Missing RF distance files
# 2025-12-02 11:26:00,555 - INFO - [SKIP S16B/RF01338] Missing RF distance files
# 2025-12-02 11:26:00,567 - INFO - [SKIP S16B/RF01380] Missing RF distance files
# 2025-12-02 11:26:00,555 - INFO - [SKIP S16B/RF01338] Missing RF distance files
# 2025-12-02 11:26:00,567 - INFO - [SKIP S16B/RF01380] Missing RF distance files
# 2025-12-02 11:26:04,468 - INFO - [SKIP S16B/RF03623] Missing RF distance files
# 2025-12-02 11:26:04,468 - INFO - [SKIP S16B/RF03623] Missing RF distance files
# 2025-12-02 11:26:04,537 - INFO - [SKIP S16B/RF03760] Missing RF distance files
# 2025-12-02 11:26:04,537 - INFO - [SKIP S16B/RF03760] Missing RF distance files
# 2025-12-02 11:26:04,661 - INFO - [SKIP S16B/RF03969] Missing RF distance files
# 2025-12-02 11:26:04,661 - INFO - [SKIP S16B/RF03969] Missing RF distance files
# 2025-12-02 11:26:05,129 - INFO - Processed S16B: 1788 RNAs
# 2025-12-02 11:26:05,129 - INFO - Processed S16B: 1788 RNAs
# 2025-12-02 11:26:05,696 - INFO - [SKIP S6A/RF00207] Missing RF distance files
# 2025-12-02 11:26:05,696 - INFO - [SKIP S6A/RF00207] Missing RF distance files
# 2025-12-02 11:26:08,738 - INFO - [SKIP S6A/RF00976] Missing RF distance files
# 2025-12-02 11:26:08,738 - INFO - [SKIP S6A/RF00976] Missing RF distance files
# 2025-12-02 11:26:08,947 - INFO - [SKIP S6A/RF01047] Missing RF distance files
# 2025-12-02 11:26:08,947 - INFO - [SKIP S6A/RF01047] Missing RF distance files
# 2025-12-02 11:26:09,797 - INFO - [SKIP S6A/RF01338] Missing RF distance files
# 2025-12-02 11:26:09,797 - INFO - [SKIP S6A/RF01338] Missing RF distance files
# 2025-12-02 11:26:09,814 - INFO - [SKIP S6A/RF01380] Missing RF distance files
# 2025-12-02 11:26:09,814 - INFO - [SKIP S6A/RF01380] Missing RF distance files
# 2025-12-02 11:26:14,750 - INFO - [SKIP S6A/RF03623] Missing RF distance files
# 2025-12-02 11:26:14,750 - INFO - [SKIP S6A/RF03623] Missing RF distance files
# 2025-12-02 11:26:14,847 - INFO - [SKIP S6A/RF03760] Missing RF distance files
# 2025-12-02 11:26:14,847 - INFO - [SKIP S6A/RF03760] Missing RF distance files
# 2025-12-02 11:26:14,979 - INFO - [SKIP S6A/RF03969] Missing RF distance files
# 2025-12-02 11:26:14,979 - INFO - [SKIP S6A/RF03969] Missing RF distance files
# 2025-12-02 11:26:15,686 - INFO - Processed S6A: 1788 RNAs
# 2025-12-02 11:26:15,686 - INFO - Processed S6A: 1788 RNAs
# 2025-12-02 11:26:16,466 - INFO - [SKIP S6B/RF00207] Missing RF distance files
# 2025-12-02 11:26:16,466 - INFO - [SKIP S6B/RF00207] Missing RF distance files
# 2025-12-02 11:26:19,608 - INFO - [SKIP S6B/RF00976] Missing RF distance files
# 2025-12-02 11:26:19,608 - INFO - [SKIP S6B/RF00976] Missing RF distance files
# 2025-12-02 11:26:19,863 - INFO - [SKIP S6B/RF01047] Missing RF distance files
# 2025-12-02 11:26:19,863 - INFO - [SKIP S6B/RF01047] Missing RF distance files
# 2025-12-02 11:26:20,586 - INFO - [SKIP S6B/RF01338] Missing RF distance files
# 2025-12-02 11:26:20,586 - INFO - [SKIP S6B/RF01338] Missing RF distance files
# 2025-12-02 11:26:20,605 - INFO - [SKIP S6B/RF01380] Missing RF distance files
# 2025-12-02 11:26:20,605 - INFO - [SKIP S6B/RF01380] Missing RF distance files
# 2025-12-02 11:26:25,196 - INFO - [SKIP S6B/RF03623] Missing RF distance files
# 2025-12-02 11:26:25,196 - INFO - [SKIP S6B/RF03623] Missing RF distance files
# 2025-12-02 11:26:25,309 - INFO - [SKIP S6B/RF03760] Missing RF distance files
# 2025-12-02 11:26:25,309 - INFO - [SKIP S6B/RF03760] Missing RF distance files
# 2025-12-02 11:26:25,737 - INFO - [SKIP S6B/RF03969] Missing RF distance files
# 2025-12-02 11:26:25,737 - INFO - [SKIP S6B/RF03969] Missing RF distance files
# 2025-12-02 11:26:26,400 - INFO - Processed S6B: 1788 RNAs
# 2025-12-02 11:26:26,400 - INFO - Processed S6B: 1788 RNAs
# 2025-12-02 11:26:27,133 - INFO - [SKIP S6C/RF00207] Missing RF distance files
# 2025-12-02 11:26:27,133 - INFO - [SKIP S6C/RF00207] Missing RF distance files
# 2025-12-02 11:26:29,923 - INFO - [SKIP S6C/RF00976] Missing RF distance files
# 2025-12-02 11:26:29,923 - INFO - [SKIP S6C/RF00976] Missing RF distance files
# 2025-12-02 11:26:30,125 - INFO - [SKIP S6C/RF01047] Missing RF distance files
# 2025-12-02 11:26:30,125 - INFO - [SKIP S6C/RF01047] Missing RF distance files
# 2025-12-02 11:26:30,892 - INFO - [SKIP S6C/RF01338] Missing RF distance files
# 2025-12-02 11:26:30,892 - INFO - [SKIP S6C/RF01338] Missing RF distance files
# 2025-12-02 11:26:30,908 - INFO - [SKIP S6C/RF01380] Missing RF distance files
# 2025-12-02 11:26:30,908 - INFO - [SKIP S6C/RF01380] Missing RF distance files
# 2025-12-02 11:26:35,406 - INFO - [SKIP S6C/RF03623] Missing RF distance files
# 2025-12-02 11:26:35,406 - INFO - [SKIP S6C/RF03623] Missing RF distance files
# 2025-12-02 11:26:35,487 - INFO - [SKIP S6C/RF03760] Missing RF distance files
# 2025-12-02 11:26:35,487 - INFO - [SKIP S6C/RF03760] Missing RF distance files
# 2025-12-02 11:26:35,635 - INFO - [SKIP S6C/RF03969] Missing RF distance files
# 2025-12-02 11:26:35,635 - INFO - [SKIP S6C/RF03969] Missing RF distance files
# 2025-12-02 11:26:36,303 - INFO - Processed S6C: 1788 RNAs
# 2025-12-02 11:26:36,303 - INFO - Processed S6C: 1788 RNAs
# 2025-12-02 11:26:37,062 - INFO - [SKIP S6D/RF00207] Missing RF distance files
# 2025-12-02 11:26:37,062 - INFO - [SKIP S6D/RF00207] Missing RF distance files
# 2025-12-02 11:26:40,721 - INFO - [SKIP S6D/RF00976] Missing RF distance files
# 2025-12-02 11:26:40,721 - INFO - [SKIP S6D/RF00976] Missing RF distance files
# 2025-12-02 11:26:40,951 - INFO - [SKIP S6D/RF01047] Missing RF distance files
# 2025-12-02 11:26:40,951 - INFO - [SKIP S6D/RF01047] Missing RF distance files
# 2025-12-02 11:26:41,781 - INFO - [SKIP S6D/RF01338] Missing RF distance files
# 2025-12-02 11:26:41,781 - INFO - [SKIP S6D/RF01338] Missing RF distance files
# 2025-12-02 11:26:41,796 - INFO - [SKIP S6D/RF01380] Missing RF distance files
# 2025-12-02 11:26:41,796 - INFO - [SKIP S6D/RF01380] Missing RF distance files
# 2025-12-02 11:26:46,227 - INFO - [SKIP S6D/RF03623] Missing RF distance files
# 2025-12-02 11:26:46,227 - INFO - [SKIP S6D/RF03623] Missing RF distance files
# 2025-12-02 11:26:46,303 - INFO - [SKIP S6D/RF03760] Missing RF distance files
# 2025-12-02 11:26:46,303 - INFO - [SKIP S6D/RF03760] Missing RF distance files
# 2025-12-02 11:26:46,429 - INFO - [SKIP S6D/RF03969] Missing RF distance files
# 2025-12-02 11:26:46,429 - INFO - [SKIP S6D/RF03969] Missing RF distance files
# 2025-12-02 11:26:47,092 - INFO - Processed S6D: 1788 RNAs
# 2025-12-02 11:26:47,092 - INFO - Processed S6D: 1788 RNAs
# 2025-12-02 11:26:47,812 - INFO - [SKIP S6E/RF00207] Missing RF distance files
# 2025-12-02 11:26:47,812 - INFO - [SKIP S6E/RF00207] Missing RF distance files
# 2025-12-02 11:26:50,642 - INFO - [SKIP S6E/RF00976] Missing RF distance files
# 2025-12-02 11:26:50,642 - INFO - [SKIP S6E/RF00976] Missing RF distance files
# 2025-12-02 11:26:50,860 - INFO - [SKIP S6E/RF01047] Missing RF distance files
# 2025-12-02 11:26:50,860 - INFO - [SKIP S6E/RF01047] Missing RF distance files
# 2025-12-02 11:26:51,634 - INFO - [SKIP S6E/RF01338] Missing RF distance files
# 2025-12-02 11:26:51,645 - INFO - [SKIP S6E/RF01380] Missing RF distance files
# 2025-12-02 11:26:51,634 - INFO - [SKIP S6E/RF01338] Missing RF distance files
# 2025-12-02 11:26:51,645 - INFO - [SKIP S6E/RF01380] Missing RF distance files
# 2025-12-02 11:26:56,225 - INFO - [SKIP S6E/RF03623] Missing RF distance files
# 2025-12-02 11:26:56,225 - INFO - [SKIP S6E/RF03623] Missing RF distance files
# 2025-12-02 11:26:56,314 - INFO - [SKIP S6E/RF03760] Missing RF distance files
# 2025-12-02 11:26:56,314 - INFO - [SKIP S6E/RF03760] Missing RF distance files
# 2025-12-02 11:26:56,446 - INFO - [SKIP S6E/RF03969] Missing RF distance files
# 2025-12-02 11:26:56,446 - INFO - [SKIP S6E/RF03969] Missing RF distance files
# 2025-12-02 11:26:57,038 - INFO - Processed S6E: 1788 RNAs
# 2025-12-02 11:26:57,038 - INFO - Processed S6E: 1788 RNAs
# 2025-12-02 11:26:57,795 - INFO - [SKIP S7A/RF00207] Missing RF distance files
# 2025-12-02 11:26:57,795 - INFO - [SKIP S7A/RF00207] Missing RF distance files
# 2025-12-02 11:27:00,440 - INFO - [SKIP S7A/RF00976] Missing RF distance files
# 2025-12-02 11:27:00,440 - INFO - [SKIP S7A/RF00976] Missing RF distance files
# 2025-12-02 11:27:00,630 - INFO - [SKIP S7A/RF01047] Missing RF distance files
# 2025-12-02 11:27:00,630 - INFO - [SKIP S7A/RF01047] Missing RF distance files
# 2025-12-02 11:27:01,250 - INFO - [SKIP S7A/RF01338] Missing RF distance files
# 2025-12-02 11:27:01,250 - INFO - [SKIP S7A/RF01338] Missing RF distance files
# 2025-12-02 11:27:01,263 - INFO - [SKIP S7A/RF01380] Missing RF distance files
# 2025-12-02 11:27:01,263 - INFO - [SKIP S7A/RF01380] Missing RF distance files
# 2025-12-02 11:27:05,084 - INFO - [SKIP S7A/RF03623] Missing RF distance files
# 2025-12-02 11:27:05,084 - INFO - [SKIP S7A/RF03623] Missing RF distance files
# 2025-12-02 11:27:05,181 - INFO - [SKIP S7A/RF03760] Missing RF distance files
# 2025-12-02 11:27:05,181 - INFO - [SKIP S7A/RF03760] Missing RF distance files
# 2025-12-02 11:27:05,317 - INFO - [SKIP S7A/RF03969] Missing RF distance files
# 2025-12-02 11:27:05,317 - INFO - [SKIP S7A/RF03969] Missing RF distance files
# 2025-12-02 11:27:05,986 - INFO - Processed S7A: 1788 RNAs
# 2025-12-02 11:27:05,986 - INFO - Processed S7A: 1788 RNAs
# 2025-12-02 11:27:06,740 - INFO - [SKIP S7B/RF00207] Missing RF distance files
# 2025-12-02 11:27:06,740 - INFO - [SKIP S7B/RF00207] Missing RF distance files
# 2025-12-02 11:27:09,741 - INFO - [SKIP S7B/RF00976] Missing RF distance files
# 2025-12-02 11:27:09,741 - INFO - [SKIP S7B/RF00976] Missing RF distance files
# 2025-12-02 11:27:09,919 - INFO - [SKIP S7B/RF01047] Missing RF distance files
# 2025-12-02 11:27:09,919 - INFO - [SKIP S7B/RF01047] Missing RF distance files
# 2025-12-02 11:27:10,451 - INFO - [SKIP S7B/RF01338] Missing RF distance files
# 2025-12-02 11:27:10,451 - INFO - [SKIP S7B/RF01338] Missing RF distance files
# 2025-12-02 11:27:10,465 - INFO - [SKIP S7B/RF01380] Missing RF distance files
# 2025-12-02 11:27:10,465 - INFO - [SKIP S7B/RF01380] Missing RF distance files
# 2025-12-02 11:27:14,728 - INFO - [SKIP S7B/RF03623] Missing RF distance files
# 2025-12-02 11:27:14,728 - INFO - [SKIP S7B/RF03623] Missing RF distance files
# 2025-12-02 11:27:14,802 - INFO - [SKIP S7B/RF03760] Missing RF distance files
# 2025-12-02 11:27:14,802 - INFO - [SKIP S7B/RF03760] Missing RF distance files
# 2025-12-02 11:27:14,944 - INFO - [SKIP S7B/RF03969] Missing RF distance files
# 2025-12-02 11:27:14,944 - INFO - [SKIP S7B/RF03969] Missing RF distance files
# 2025-12-02 11:27:15,588 - INFO - Processed S7B: 1788 RNAs
# 2025-12-02 11:27:15,588 - INFO - Processed S7B: 1788 RNAs
# 2025-12-02 11:27:16,334 - INFO - [SKIP S7C/RF00207] Missing RF distance files
# 2025-12-02 11:27:16,334 - INFO - [SKIP S7C/RF00207] Missing RF distance files
# 2025-12-02 11:27:19,374 - INFO - [SKIP S7C/RF00976] Missing RF distance files
# 2025-12-02 11:27:19,374 - INFO - [SKIP S7C/RF00976] Missing RF distance files
# 2025-12-02 11:27:19,589 - INFO - [SKIP S7C/RF01047] Missing RF distance files
# 2025-12-02 11:27:19,589 - INFO - [SKIP S7C/RF01047] Missing RF distance files
# 2025-12-02 11:27:20,379 - INFO - [SKIP S7C/RF01338] Missing RF distance files
# 2025-12-02 11:27:20,379 - INFO - [SKIP S7C/RF01338] Missing RF distance files
# 2025-12-02 11:27:20,390 - INFO - [SKIP S7C/RF01380] Missing RF distance files
# 2025-12-02 11:27:20,390 - INFO - [SKIP S7C/RF01380] Missing RF distance files
# 2025-12-02 11:27:25,124 - INFO - [SKIP S7C/RF03623] Missing RF distance files
# 2025-12-02 11:27:25,124 - INFO - [SKIP S7C/RF03623] Missing RF distance files
# 2025-12-02 11:27:25,221 - INFO - [SKIP S7C/RF03760] Missing RF distance files
# 2025-12-02 11:27:25,221 - INFO - [SKIP S7C/RF03760] Missing RF distance files
# 2025-12-02 11:27:25,357 - INFO - [SKIP S7C/RF03969] Missing RF distance files
# 2025-12-02 11:27:25,357 - INFO - [SKIP S7C/RF03969] Missing RF distance files
# 2025-12-02 11:27:26,016 - INFO - Processed S7C: 1788 RNAs
# 2025-12-02 11:27:26,016 - INFO - Processed S7C: 1788 RNAs
# 2025-12-02 11:27:26,778 - INFO - [SKIP S7D/RF00207] Missing RF distance files
# 2025-12-02 11:27:26,778 - INFO - [SKIP S7D/RF00207] Missing RF distance files
# 2025-12-02 11:27:29,725 - INFO - [SKIP S7D/RF00976] Missing RF distance files
# 2025-12-02 11:27:29,725 - INFO - [SKIP S7D/RF00976] Missing RF distance files
# 2025-12-02 11:27:29,919 - INFO - [SKIP S7D/RF01047] Missing RF distance files
# 2025-12-02 11:27:29,919 - INFO - [SKIP S7D/RF01047] Missing RF distance files
# 2025-12-02 11:27:30,595 - INFO - [SKIP S7D/RF01338] Missing RF distance files
# 2025-12-02 11:27:30,595 - INFO - [SKIP S7D/RF01338] Missing RF distance files
# 2025-12-02 11:27:30,609 - INFO - [SKIP S7D/RF01380] Missing RF distance files
# 2025-12-02 11:27:30,609 - INFO - [SKIP S7D/RF01380] Missing RF distance files
# 2025-12-02 11:27:35,202 - INFO - [SKIP S7D/RF03623] Missing RF distance files
# 2025-12-02 11:27:35,202 - INFO - [SKIP S7D/RF03623] Missing RF distance files
# 2025-12-02 11:27:35,280 - INFO - [SKIP S7D/RF03760] Missing RF distance files
# 2025-12-02 11:27:35,280 - INFO - [SKIP S7D/RF03760] Missing RF distance files
# 2025-12-02 11:27:35,394 - INFO - [SKIP S7D/RF03969] Missing RF distance files
# 2025-12-02 11:27:35,394 - INFO - [SKIP S7D/RF03969] Missing RF distance files
# 2025-12-02 11:27:36,041 - INFO - Processed S7D: 1788 RNAs
# 2025-12-02 11:27:36,041 - INFO - Processed S7D: 1788 RNAs
# 2025-12-02 11:27:36,796 - INFO - [SKIP S7E/RF00207] Missing RF distance files
# 2025-12-02 11:27:36,796 - INFO - [SKIP S7E/RF00207] Missing RF distance files
# 2025-12-02 11:27:39,467 - INFO - [SKIP S7E/RF00976] Missing RF distance files
# 2025-12-02 11:27:39,467 - INFO - [SKIP S7E/RF00976] Missing RF distance files
# 2025-12-02 11:27:39,708 - INFO - [SKIP S7E/RF01047] Missing RF distance files
# 2025-12-02 11:27:39,708 - INFO - [SKIP S7E/RF01047] Missing RF distance files
# 2025-12-02 11:27:40,447 - INFO - [SKIP S7E/RF01338] Missing RF distance files
# 2025-12-02 11:27:40,447 - INFO - [SKIP S7E/RF01338] Missing RF distance files
# 2025-12-02 11:27:40,460 - INFO - [SKIP S7E/RF01380] Missing RF distance files
# 2025-12-02 11:27:40,460 - INFO - [SKIP S7E/RF01380] Missing RF distance files
# 2025-12-02 11:27:44,979 - INFO - [SKIP S7E/RF03623] Missing RF distance files
# 2025-12-02 11:27:44,979 - INFO - [SKIP S7E/RF03623] Missing RF distance files
# 2025-12-02 11:27:45,038 - INFO - [SKIP S7E/RF03760] Missing RF distance files
# 2025-12-02 11:27:45,038 - INFO - [SKIP S7E/RF03760] Missing RF distance files
# 2025-12-02 11:27:45,123 - INFO - [SKIP S7E/RF03969] Missing RF distance files
# 2025-12-02 11:27:45,123 - INFO - [SKIP S7E/RF03969] Missing RF distance files
# 2025-12-02 11:27:45,534 - INFO - Processed S7E: 1788 RNAs
# 2025-12-02 11:27:45,534 - INFO - Processed S7E: 1788 RNAs
# 2025-12-02 11:27:46,137 - INFO - [SKIP S7F/RF00207] Missing RF distance files
# 2025-12-02 11:27:46,137 - INFO - [SKIP S7F/RF00207] Missing RF distance files
# 2025-12-02 11:27:49,317 - INFO - [SKIP S7F/RF00976] Missing RF distance files
# 2025-12-02 11:27:49,317 - INFO - [SKIP S7F/RF00976] Missing RF distance files
# 2025-12-02 11:27:49,555 - INFO - [SKIP S7F/RF01047] Missing RF distance files
# 2025-12-02 11:27:49,555 - INFO - [SKIP S7F/RF01047] Missing RF distance files
# 2025-12-02 11:27:50,331 - INFO - [SKIP S7F/RF01338] Missing RF distance files
# 2025-12-02 11:27:50,331 - INFO - [SKIP S7F/RF01338] Missing RF distance files
# 2025-12-02 11:27:50,345 - INFO - [SKIP S7F/RF01380] Missing RF distance files
# 2025-12-02 11:27:50,345 - INFO - [SKIP S7F/RF01380] Missing RF distance files
# 2025-12-02 11:27:55,046 - INFO - [SKIP S7F/RF03623] Missing RF distance files
# 2025-12-02 11:27:55,046 - INFO - [SKIP S7F/RF03623] Missing RF distance files
# 2025-12-02 11:27:55,140 - INFO - [SKIP S7F/RF03760] Missing RF distance files
# 2025-12-02 11:27:55,140 - INFO - [SKIP S7F/RF03760] Missing RF distance files
# 2025-12-02 11:27:55,277 - INFO - [SKIP S7F/RF03969] Missing RF distance files
# 2025-12-02 11:27:55,277 - INFO - [SKIP S7F/RF03969] Missing RF distance files
# 2025-12-02 11:27:55,996 - INFO - Processed S7F: 1788 RNAs
# 2025-12-02 11:27:55,996 - INFO - Processed S7F: 1788 RNAs
# 2025-12-02 11:27:56,359 - INFO - Saved: /Users/u7875558/RNAPhylo/seedAlignment_AllModels/outputs/SEED_Utest_all_models_long.csv (25032 rows)
# 2025-12-02 11:27:56,360 - INFO - Saved: /Users/u7875558/RNAPhylo/seedAlignment_AllModels/outputs/SEED_Utest_all_models_wide.csv
# 2025-12-02 11:27:56,360 - INFO - Saved: /Users/u7875558/RNAPhylo/seedAlignment_AllModels/outputs/SEED_Median_nRF_all_models_long.csv (25032 rows)
# 2025-12-02 11:27:56,359 - INFO - Saved: /Users/u7875558/RNAPhylo/seedAlignment_AllModels/outputs/SEED_Utest_all_models_long.csv (25032 rows)
# 2025-12-02 11:27:56,360 - INFO - Saved: /Users/u7875558/RNAPhylo/seedAlignment_AllModels/outputs/SEED_Utest_all_models_wide.csv
# 2025-12-02 11:27:56,360 - INFO - Saved: /Users/u7875558/RNAPhylo/seedAlignment_AllModels/outputs/SEED_Median_nRF_all_models_long.csv (25032 rows)
# ✓ Completed: 25032 RNAs processed across 14 models
# ✓ Output CSV files saved to /Users/u7875558/RNAPhylo/seedAlignment_AllModels/outputs

# %%
#!/usr/bin/env python3
"""
Diagnostic: List RNA families with/without .rfdist files
"""

import os
from os.path import join, isdir, isfile

DIR_WORKING   = "/Users/u7875558/RNAPhylo/seedAlignment_AllModels"
DIR_OUTPUTS   = join(DIR_WORKING, "outputs")
DIR_RF        = join(DIR_OUTPUTS, "251121_Robinson_Foulds")
DIR_DNA_extra = join(DIR_RF, "DNA_extra")

print("="*70)
print("DIAGNOSTIC: RNA families .rfdist file status")
print("="*70)

# Check DNA_extra folder
print("\n[DNA_extra folder]")
if isdir(DIR_DNA_extra):
    rna_dirs = sorted([d for d in os.listdir(DIR_DNA_extra) if isdir(join(DIR_DNA_extra, d))])
    has_rfdist = []
    missing_rfdist = []
    
    for rna in rna_dirs:
        rfdist_path = join(DIR_DNA_extra, rna, f"{rna}.rfdist")
        if isfile(rfdist_path):
            has_rfdist.append(rna)
        else:
            missing_rfdist.append(rna)
    
    print(f"Total RNA families: {len(rna_dirs)}")
    print(f"✓ WITH .rfdist: {len(has_rfdist)}")
    if missing_rfdist:
        print(f"✗ WITHOUT .rfdist: {len(missing_rfdist)}")
        for rna in missing_rfdist:
            print(f"    - {rna}")
else:
    print(f"✗ Directory not found: {DIR_DNA_extra}")

# Check S* model folders
print("\n[S* model folders]")
models = sorted([m for m in os.listdir(DIR_RF) if isdir(join(DIR_RF, m)) and m.startswith('S')])

for model in models:
    model_dir = join(DIR_RF, model)
    rna_dirs = sorted([d for d in os.listdir(model_dir) if isdir(join(model_dir, d))])
    
    has_rfdist = []
    missing_rfdist = []
    
    for rna in rna_dirs:
        rfdist_path = join(model_dir, rna, f"{rna}.rfdist")
        if isfile(rfdist_path):
            has_rfdist.append(rna)
        else:
            missing_rfdist.append(rna)
    
    print(f"\n{model}:")
    print(f"  Total RNA families: {len(rna_dirs)}")
    print(f"  ✓ WITH .rfdist: {len(has_rfdist)}")
    if missing_rfdist:
        print(f"  ✗ WITHOUT .rfdist: {len(missing_rfdist)}")
        for rna in missing_rfdist:
            print(f"      - {rna}")

print("\n" + "="*70)
# Out:
# ======================================================================
# DIAGNOSTIC: RNA families .rfdist file status
# ======================================================================
#
# [DNA_extra folder]
# Total RNA families: 2260
# ✓ WITH .rfdist: 2260
#
# [S* model folders]
#
# S16:
#   Total RNA families: 1796
#   ✓ WITH .rfdist: 1788
#   ✗ WITHOUT .rfdist: 8
#       - RF00207
#       - RF00976
#       - RF01047
#       - RF01338
#       - RF01380
#       - RF03623
#       - RF03760
#       - RF03969
#
# S16A:
#   Total RNA families: 1796
#   ✓ WITH .rfdist: 1788
#   ✗ WITHOUT .rfdist: 8
#       - RF00207
#       - RF00976
#       - RF01047
#       - RF01338
#       - RF01380
#       - RF03623
#       - RF03760
#       - RF03969
#
# S16B:
#   Total RNA families: 1796
#   ✓ WITH .rfdist: 1788
#   ✗ WITHOUT .rfdist: 8
#       - RF00207
#       - RF00976
#       - RF01047
#       - RF01338
#       - RF01380
#       - RF03623
#       - RF03760
#       - RF03969
#
# S6A:
#   Total RNA families: 1796
#   ✓ WITH .rfdist: 1788
#   ✗ WITHOUT .rfdist: 8
#       - RF00207
#       - RF00976
#       - RF01047
#       - RF01338
#       - RF01380
#       - RF03623
#       - RF03760
#       - RF03969
#
# S6B:
#   Total RNA families: 1796
#   ✓ WITH .rfdist: 1788
#   ✗ WITHOUT .rfdist: 8
#       - RF00207
#       - RF00976
#       - RF01047
#       - RF01338
#       - RF01380
#       - RF03623
#       - RF03760
#       - RF03969
#
# S6C:
#   Total RNA families: 1796
#   ✓ WITH .rfdist: 1788
#   ✗ WITHOUT .rfdist: 8
#       - RF00207
#       - RF00976
#       - RF01047
#       - RF01338
#       - RF01380
#       - RF03623
#       - RF03760
#       - RF03969
#
# S6D:
#   Total RNA families: 1796
#   ✓ WITH .rfdist: 1788
#   ✗ WITHOUT .rfdist: 8
#       - RF00207
#       - RF00976
#       - RF01047
#       - RF01338
#       - RF01380
#       - RF03623
#       - RF03760
#       - RF03969
#
# S6E:
#   Total RNA families: 1796
#   ✓ WITH .rfdist: 1788
#   ✗ WITHOUT .rfdist: 8
#       - RF00207
#       - RF00976
#       - RF01047
#       - RF01338
#       - RF01380
#       - RF03623
#       - RF03760
#       - RF03969
#
# S7A:
#   Total RNA families: 1796
#   ✓ WITH .rfdist: 1788
#   ✗ WITHOUT .rfdist: 8
#       - RF00207
#       - RF00976
#       - RF01047
#       - RF01338
#       - RF01380
#       - RF03623
#       - RF03760
#       - RF03969
#
# S7B:
#   Total RNA families: 1796
#   ✓ WITH .rfdist: 1788
#   ✗ WITHOUT .rfdist: 8
#       - RF00207
#       - RF00976
#       - RF01047
#       - RF01338
#       - RF01380
#       - RF03623
#       - RF03760
#       - RF03969
#
# S7C:
#   Total RNA families: 1796
#   ✓ WITH .rfdist: 1788
#   ✗ WITHOUT .rfdist: 8
#       - RF00207
#       - RF00976
#       - RF01047
#       - RF01338
#       - RF01380
#       - RF03623
#       - RF03760
#       - RF03969
#
# S7D:
#   Total RNA families: 1796
#   ✓ WITH .rfdist: 1788
#   ✗ WITHOUT .rfdist: 8
#       - RF00207
#       - RF00976
#       - RF01047
#       - RF01338
#       - RF01380
#       - RF03623
#       - RF03760
#       - RF03969
#
# S7E:
#   Total RNA families: 1796
#   ✓ WITH .rfdist: 1788
#   ✗ WITHOUT .rfdist: 8
#       - RF00207
#       - RF00976
#       - RF01047
#       - RF01338
#       - RF01380
#       - RF03623
#       - RF03760
#       - RF03969
#
# S7F:
#   Total RNA families: 1796
#   ✓ WITH .rfdist: 1788
#   ✗ WITHOUT .rfdist: 8
#       - RF00207
#       - RF00976
#       - RF01047
#       - RF01338
#       - RF01380
#       - RF03623
#       - RF03760
#       - RF03969
#
# ======================================================================

# %% [markdown]
# # Figures

# %% [markdown]
# ## 1. SEED

# %%
import re
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# --- 1) Build plotting frame without touching df_medians -----------------------
# Baseline: only from DNA_extra, rename to "DNA vs DNA"
base_mask = (seed_medians['Model'] == 'DNA_extra') & (seed_medians['Category'] == 'DNA vs extra DNA')
df_base = (
    seed_medians.loc[base_mask, ['RNA', 'Median nRF']].copy()
               .assign(Group='DNA vs DNA')
)

# S-models: keep DNA vs RNA rows from all non-DNA_extra models
df_models = seed_medians[
    (seed_medians['Model'] != 'DNA_extra')
    & (seed_medians['Category'].str.startswith('DNA vs RNA'))
].copy()

# Ensure the group label is "DNA vs RNA (MODEL)" (if not already)
def ensure_group(row):
    cat = str(row['Category'])
    if '(' in cat and ')' in cat:
        return cat
    return f"DNA vs RNA ({row['Model']})"

df_models['Group'] = df_models.apply(ensure_group, axis=1)

# Combine for plotting
df_plot = pd.concat(
    [df_base[['RNA','Group','Median nRF']], df_models[['RNA','Group','Median nRF']]],
    ignore_index=True
).dropna(subset=['Median nRF'])

# --- 2) Order groups: baseline → S16* → S7* → S6* ------------------------------
all_groups = sorted(df_plot['Group'].unique())

def pick(prefix):
    return sorted([g for g in all_groups if re.search(rf'\({prefix}', g)],
                  key=lambda g: re.search(r'\(([^)]+)\)', g).group(1))

order = ['DNA vs DNA']
order += pick('S16') + pick('S7') + pick('S6')

# --- 3) Colors -----------------------------------------------------------------
palette = {'DNA vs DNA': '#d3d3d3'}  # light gray baseline

def shade(groups, cmap):
    if not groups: return {}
    cols = sns.color_palette(cmap, len(groups))
    return {g: cols[i] for i, g in enumerate(groups)}

palette |= shade([g for g in order if '(S16' in g], 'Oranges')
palette |= shade([g for g in order if '(S7'  in g], 'Blues')
palette |= shade([g for g in order if '(S6'  in g], 'Greens')

# --- 4) Plot with median trend line ---------------------------------------------------
plt.figure(figsize=(max(10, 0.6*len(order)), 5))
sns.violinplot(
    data=df_plot[df_plot['Group'].isin(order)],
    x='Group', y='Median nRF',
    order=order, palette=palette,
    cut=0,           # cut only at the bottom (no extension below 0)
    inner=None
)

# Add median trend line across groups
xpos = np.arange(len(order))
medians = [df_plot[df_plot['Group'] == g]['Median nRF'].median() for g in order]
plt.plot(xpos, medians, color='black', linewidth=2.5, marker='o', markersize=6, 
         label='Median across RNAs', zorder=10)

plt.xticks(rotation=30, ha='right')
plt.ylabel('Median Normalised RF')
plt.xlabel('')
plt.title('Median Normalised Robinson-Foulds Distance -- All Models for seed-alignment dataset')
plt.legend(loc='upper left', fontsize=10)
plt.tight_layout()
plt.show()

# --- 5) Quick summaries (optional) ---------------------------------------------
print('Group medians:')
print(df_plot.groupby('Group')['Median nRF'].median().reindex(order).round(4))
print('\nGroup means:')
print(df_plot.groupby('Group')['Median nRF'].mean().reindex(order).round(4))
# Out:
# /var/folders/7l/28yzqfm93j105y85x5rns4bryc93vy/T/ipykernel_7361/1663583315.py:60: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# Group medians:
# Group
# DNA vs DNA              NaN
# DNA vs RNA (S16)     0.2667
# DNA vs RNA (S16A)    0.2222
# DNA vs RNA (S16B)    0.2727
# DNA vs RNA (S7A)     0.2500
# DNA vs RNA (S7B)     0.2500
# DNA vs RNA (S7C)     0.2353
# DNA vs RNA (S7D)     0.2222
# DNA vs RNA (S7E)     0.2240
# DNA vs RNA (S7F)     0.2143
# DNA vs RNA (S6A)     0.2727
# DNA vs RNA (S6B)     0.2500
# DNA vs RNA (S6C)     0.2500
# DNA vs RNA (S6D)     0.2500
# DNA vs RNA (S6E)     0.2500
# Name: Median nRF, dtype: float64
#
# Group means:
# Group
# DNA vs DNA              NaN
# DNA vs RNA (S16)     0.2975
# DNA vs RNA (S16A)    0.2681
# DNA vs RNA (S16B)    0.3018
# DNA vs RNA (S7A)     0.2847
# DNA vs RNA (S7B)     0.2792
# DNA vs RNA (S7C)     0.2788
# DNA vs RNA (S7D)     0.2716
# DNA vs RNA (S7E)     0.2740
# DNA vs RNA (S7F)     0.2689
# DNA vs RNA (S6A)     0.3078
# DNA vs RNA (S6B)     0.3006
# DNA vs RNA (S6C)     0.2991
# DNA vs RNA (S6D)     0.2994
# DNA vs RNA (S6E)     0.3016
# Name: Median nRF, dtype: float64

# %%
#!/usr/bin/env python3
"""
Compute median normalised RF distances for DNA_extra (DNA vs DNA_extra)
Append results to seed_medians, and save all median nRF data to CSV
"""

import os
import glob
import numpy as np
import pandas as pd
from os.path import join, isdir, isfile
from Bio import Phylo

# ─── PATHS ────────────────────────────────────────────────────────────────────
DIR_WORKING   = "/Users/u7875558/RNAPhylo/seedAlignment_AllModels"
DIR_OUTPUTS   = join(DIR_WORKING, "outputs")
DIR_TREES     = join(DIR_OUTPUTS, "inferred_trees")
DIR_DNA       = join(DIR_TREES, "DNA")
DIR_RF        = join(DIR_OUTPUTS, "251121_Robinson_Foulds")
DIR_DNA_extra = join(DIR_RF, "DNA_extra")

# ─── HELPER FUNCTIONS ─────────────────────────────────────────────────────────
def choose_first_existing(pattern_list):
    """Return first existing file/dir from list of candidate paths."""
    for p in pattern_list:
        if isfile(p):
            return p
    return None

def read_rfdist_matrix(path: str) -> np.ndarray:
    """Read IQ-TREE tab/space-separated distance matrix."""
    if not isfile(path):
        return np.array([])
    try:
        with open(path, 'r') as f:
            lines = f.readlines()
        rows = []
        for line in lines[1:]:  # skip header
            parts = line.strip().split()
            if len(parts) > 1:
                rows.append(list(map(float, parts[1:])))  # skip row label
        return np.array(rows, dtype=float) if rows else np.array([])
    except Exception as e:
        print(f"Error reading {path}: {e}")
        return np.array([])

def normalize_rf_matrix_by_n(mat: np.ndarray, n_taxa: int) -> np.ndarray:
    """Normalize RF distances: nRF = RF / (2*(n-3)) for unrooted binary trees."""
    if mat.size == 0 or n_taxa < 4:
        return np.array([])
    if np.nanmax(mat) <= 1.0 + 1e-9:  # already normalized
        return mat.copy()
    denom = 2 * (n_taxa - 3)
    return mat / denom if denom > 0 else mat.copy()

def count_taxa(tree_path: str) -> int | None:
    """Count terminals in Newick tree."""
    try:
        with open(tree_path, 'r') as fh:
            tree = next(Phylo.parse(fh, 'newick'))
        return len(tree.get_terminals())
    except Exception:
        return None

# ─── PROCESS DNA_EXTRA ─────────────────────────────────────────────────────────
print("="*70)
print("Processing DNA_extra for median normalised RF distances")
print("="*70)

dna_extra_results = []

if isdir(DIR_DNA_extra):
    rna_dirs = sorted([d for d in os.listdir(DIR_DNA_extra) if isdir(join(DIR_DNA_extra, d))])
    
    for rna in rna_dirs:
        # Read RF distance matrices (DNA vs DNA_extra)
        dna_rfdist = choose_first_existing([
            join(DIR_DNA_extra, rna, f"{rna}.rfdist"),
            join(DIR_DNA_extra, rna, f"{rna}.txt")
        ])
        
        if not dna_rfdist:
            print(f"[SKIP {rna}] No .rfdist file found")
            continue
        
        # Read matrix
        mat = read_rfdist_matrix(dna_rfdist)
        if mat.size == 0:
            print(f"[SKIP {rna}] Empty RF matrix")
            continue
        
        # Count taxa from DNA tree
        tree_pattern = join(DIR_DNA, rna, "RAxML_bestTree.*")
        tree_file = choose_first_existing(glob.glob(tree_pattern))
        
        if not tree_file:
            print(f"[SKIP {rna}] No tree found for taxa count")
            continue
        
        n_taxa = count_taxa(tree_file)
        if n_taxa is None or n_taxa < 4:
            print(f"[SKIP {rna}] Invalid taxa count: {n_taxa}")
            continue
        
        # Normalize matrix
        mat_norm = normalize_rf_matrix_by_n(mat, n_taxa)
        if mat_norm.size == 0:
            print(f"[SKIP {rna}] Normalization failed")
            continue
        
        # Extract lower triangle (pairwise distances)
        vals = mat_norm[np.tril_indices_from(mat_norm, k=-1)]
        if len(vals) < 1:
            print(f"[SKIP {rna}] No distance values")
            continue
        
        # Compute median
        median_nrf = np.median(vals)
        
        dna_extra_results.append({
            'RNA': rna,
            'Model': 'DNA_extra',
            'Category': 'DNA vs extra DNA',
            'DNA_nRF_median': np.median(vals),
            'Model_nRF_median': median_nrf,
            'Median nRF': median_nrf,
            'n_taxa': n_taxa
        })
        
        print(f"✓ {rna}: median nRF = {median_nrf:.4f}")
    
    print(f"\n✓ Processed {len(dna_extra_results)} RNA families from DNA_extra")
else:
    print(f"✗ Directory not found: {DIR_DNA_extra}")

# ─── APPEND TO seed_medians ───────────────────────────────────────────────────
if dna_extra_results:
    # First, remove existing DNA_extra rows to avoid duplicates (in case cell is re-run)
    seed_medians = seed_medians[seed_medians['Model'] != 'DNA_extra'].copy()
    
    df_dna_extra = pd.DataFrame(dna_extra_results)
    seed_medians = pd.concat([seed_medians, df_dna_extra], ignore_index=True)
    print(f"\n✓ Appended DNA_extra to seed_medians (duplicate rows removed)")
    print(f"  New total rows: {len(seed_medians)}")
    print(f"  DNA_extra rows: {len(df_dna_extra)}")
else:
    print("\n✗ No DNA_extra data to append")

# ─── CREATE COMPARISON COLUMN AND SAVE TO CSV ─────────────────────────────────
print("\n" + "="*70)
print("Creating CSV with median normalised RF distances")
print("="*70)

# Create 'Comparison' column from Model and Category
def create_comparison(row):
    """Create comparison label from Model and Category."""
    if row['Category'] == 'DNA vs extra DNA':
        return 'DNA vs DNA_extra'
    elif row['Category'] == 'DNA vs RNA':
        return f"DNA vs {row['Model']}"
    else:
        return f"{row['Category']}"

seed_medians['Comparison'] = seed_medians.apply(create_comparison, axis=1)

# Select and reorder columns for output CSV
output_df = seed_medians[['RNA', 'Comparison', 'Median nRF']].copy()

# Save to CSV
output_csv = join(DIR_OUTPUTS, 'SEED_Median_nRF_with_DNA_extra.csv')
output_df.to_csv(output_csv, index=False)

print(f"✓ Saved to: {output_csv}")
print(f"  Total rows: {len(output_df)}")
print(f"\nFirst 5 rows:")
print(output_df.head())

print("\n" + "="*70)
# Out:
# ======================================================================
# Processing DNA_extra for median normalised RF distances
# ======================================================================
# ✓ RF00001: median nRF = 0.4119
# ✓ RF00002: median nRF = 0.1897
# ✓ RF00003: median nRF = 0.2400
# ✓ RF00004: median nRF = 0.4323
# ✓ RF00005: median nRF = 0.5284
# ✓ RF00006: median nRF = 0.5797
# ✓ RF00007: median nRF = 0.3036
# ✓ RF00008: median nRF = 0.5122
# ✓ RF00009: median nRF = 0.2124
# ✓ RF00010: median nRF = 0.3055
# ✓ RF00011: median nRF = 0.1441
# ✓ RF00012: median nRF = 0.2222
# ✓ RF00013: median nRF = 0.3034
# ✓ RF00014: median nRF = 0.0000
# ✓ RF00015: median nRF = 0.3154
# ✓ RF00016: median nRF = 0.0000
# ✓ RF00017: median nRF = 0.1233
# ✓ RF00018: median nRF = 0.1714
# ✓ RF00019: median nRF = 0.4396
# ✓ RF00020: median nRF = 0.3841
# ✓ RF00021: median nRF = 0.2500
# ✓ RF00022: median nRF = 0.0000
# ✓ RF00023: median nRF = 0.2190
# ✓ RF00024: median nRF = 0.1176
# ✓ RF00025: median nRF = 0.0556
# ✓ RF00026: median nRF = 0.5390
# ✓ RF00027: median nRF = 0.1897
# ✓ RF00028: median nRF = 0.0000
# ✓ RF00029: median nRF = 0.2045
# ✓ RF00030: median nRF = 0.1935
# ✓ RF00031: median nRF = 0.4655
# ✓ RF00032: median nRF = 0.4348
# ✓ RF00033: median nRF = 0.0000
# ✓ RF00034: median nRF = 0.6000
# ✓ RF00036: median nRF = 0.5645
# ✓ RF00037: median nRF = 0.4237
# ✓ RF00038: median nRF = 0.0000
# ✓ RF00039: median nRF = 0.0000
# ✓ RF00040: median nRF = 0.0000
# ✓ RF00041: median nRF = 0.4912
# ✓ RF00042: median nRF = 0.1471
# ✓ RF00043: median nRF = 0.0000
# ✓ RF00044: median nRF = 0.0000
# ✓ RF00045: median nRF = 0.1429
# ✓ RF00046: median nRF = 0.0000
# ✓ RF00047: median nRF = 0.2075
# ✓ RF00048: median nRF = 0.4151
# ✓ RF00049: median nRF = 0.3273
# ✓ RF00050: median nRF = 0.5563
# ✓ RF00051: median nRF = 0.2222
# ✓ RF00052: median nRF = 0.0000
# ✓ RF00053: median nRF = 0.5405
# ✓ RF00054: median nRF = 0.0000
# ✓ RF00055: median nRF = 0.5000
# ✓ RF00056: median nRF = 0.3243
# ✓ RF00057: median nRF = 0.3478
# ✓ RF00058: median nRF = 0.0000
# ✓ RF00059: median nRF = 0.4818
# ✓ RF00060: median nRF = 0.0000
# ✓ RF00061: median nRF = 0.3617
# ✓ RF00062: median nRF = 0.0000
# ✓ RF00063: median nRF = 0.0000
# ✓ RF00064: median nRF = 0.0000
# ✓ RF00065: median nRF = 0.0000
# ✓ RF00066: median nRF = 0.2826
# ✓ RF00067: median nRF = 0.0000
# ✓ RF00068: median nRF = 0.0000
# ✓ RF00069: median nRF = 0.0000
# ✓ RF00070: median nRF = 0.0000
# ✓ RF00071: median nRF = 0.2727
# ✓ RF00072: median nRF = 0.0000
# ✓ RF00073: median nRF = 0.0000
# ✓ RF00074: median nRF = 0.3429
# ✓ RF00075: median nRF = 0.1786
# ✓ RF00076: median nRF = 0.3707
# ✓ RF00077: median nRF = 0.0000
# ✓ RF00078: median nRF = 0.2857
# ✓ RF00079: median nRF = 0.1111
# ✓ RF00080: median nRF = 0.0385
# ✓ RF00081: median nRF = 0.2000
# ✓ RF00082: median nRF = 0.0000
# ✓ RF00083: median nRF = 0.0000
# ✓ RF00084: median nRF = 0.0000
# ✓ RF00085: median nRF = 0.3529
# ✓ RF00086: median nRF = 0.0000
# ✓ RF00087: median nRF = 0.2857
# ✓ RF00088: median nRF = 0.2353
# ✓ RF00089: median nRF = 0.4783
# ✓ RF00090: median nRF = 0.0476
# ✓ RF00091: median nRF = 0.0000
# ✓ RF00092: median nRF = 0.0000
# ✓ RF00093: median nRF = 0.0000
# ✓ RF00094: median nRF = 0.2000
# ✓ RF00095: median nRF = 0.4091
# ✓ RF00096: median nRF = 0.0385
# ✓ RF00097: median nRF = 0.6364
# ✓ RF00099: median nRF = 0.4565
# ✓ RF00100: median nRF = 0.4286
# ✓ RF00101: median nRF = 0.0000
# ✓ RF00102: median nRF = 0.1154
# ✓ RF00103: median nRF = 0.4397
# ✓ RF00104: median nRF = 0.1765
# ✓ RF00105: median nRF = 0.4483
# ✓ RF00106: median nRF = 0.1667
# ✓ RF00107: median nRF = 0.0000
# ✓ RF00108: median nRF = 0.4444
# ✓ RF00109: median nRF = 0.2000
# ✓ RF00110: median nRF = 0.0000
# ✓ RF00111: median nRF = 0.2143
# ✓ RF00112: median nRF = 0.1538
# ✓ RF00113: median nRF = 0.0000
# ✓ RF00114: median nRF = 0.3065
# ✓ RF00115: median nRF = 0.0000
# ✓ RF00116: median nRF = 0.0000
# ✓ RF00117: median nRF = 0.6000
# ✓ RF00118: median nRF = 0.2500
# ✓ RF00119: median nRF = 0.0000
# ✓ RF00121: median nRF = 0.0000
# ✓ RF00122: median nRF = 0.0000
# ✓ RF00124: median nRF = 0.0000
# ✓ RF00125: median nRF = 0.0000
# ✓ RF00126: median nRF = 0.0000
# ✓ RF00127: median nRF = 0.6400
# ✓ RF00128: median nRF = 0.0000
# ✓ RF00129: median nRF = 0.4386
# ✓ RF00130: median nRF = 0.3250
# ✓ RF00131: median nRF = 0.3692
# ✓ RF00132: median nRF = 0.0000
# ✓ RF00133: median nRF = 0.2273
# ✓ RF00134: median nRF = 0.0000
# ✓ RF00135: median nRF = 0.0000
# ✓ RF00136: median nRF = 0.6842
# ✓ RF00137: median nRF = 0.0000
# ✓ RF00138: median nRF = 0.0000
# ✓ RF00139: median nRF = 0.5385
# ✓ RF00140: median nRF = 0.3235
# ✓ RF00142: median nRF = 0.0000
# ✓ RF00143: median nRF = 0.2333
# ✓ RF00144: median nRF = 0.2069
# ✓ RF00145: median nRF = 0.1250
# ✓ RF00147: median nRF = 0.0000
# ✓ RF00149: median nRF = 0.0000
# ✓ RF00150: median nRF = 0.2500
# ✓ RF00151: median nRF = 0.4667
# ✓ RF00152: median nRF = 0.1739
# ✓ RF00153: median nRF = 0.6000
# ✓ RF00154: median nRF = 0.4500
# ✓ RF00155: median nRF = 0.0455
# ✓ RF00156: median nRF = 0.4250
# ✓ RF00157: median nRF = 0.4000
# ✓ RF00158: median nRF = 0.4167
# ✓ RF00159: median nRF = 0.0000
# ✓ RF00160: median nRF = 0.0000
# ✓ RF00161: median nRF = 0.5000
# ✓ RF00162: median nRF = 0.4912
# ✓ RF00163: median nRF = 0.3462
# ✓ RF00164: median nRF = 0.3333
# ✓ RF00165: median nRF = 0.2857
# ✓ RF00166: median nRF = 0.0690
# ✓ RF00167: median nRF = 0.4538
# ✓ RF00168: median nRF = 0.0455
# ✓ RF00169: median nRF = 0.3706
# ✓ RF00170: median nRF = 0.0000
# ✓ RF00171: median nRF = 0.0000
# ✓ RF00172: median nRF = 0.0000
# ✓ RF00174: median nRF = 0.3944
# ✓ RF00175: median nRF = 0.6418
# ✓ RF00176: median nRF = 0.3333
# ✓ RF00177: median nRF = 0.3750
# ✓ RF00178: median nRF = 0.3409
# ✓ RF00179: median nRF = 0.0000
# ✓ RF00180: median nRF = 0.0000
# ✓ RF00181: median nRF = 0.2857
# ✓ RF00182: median nRF = 0.0000
# ✓ RF00183: median nRF = 0.1538
# ✓ RF00184: median nRF = 0.0000
# ✓ RF00185: median nRF = 0.4051
# ✓ RF00186: median nRF = 0.4286
# ✓ RF00187: median nRF = 0.2857
# ✓ RF00188: median nRF = 0.4474
# ✓ RF00189: median nRF = 0.0000
# ✓ RF00190: median nRF = 0.2692
# ✓ RF00191: median nRF = 0.1364
# ✓ RF00193: median nRF = 0.1667
# ✓ RF00194: median nRF = 0.4545
# ✓ RF00195: median nRF = 0.1250
# ✓ RF00196: median nRF = 0.0000
# ✓ RF00198: median nRF = 0.0000
# ✓ RF00199: median nRF = 0.0000
# ✓ RF00200: median nRF = 0.0000
# ✓ RF00201: median nRF = 0.0000
# ✓ RF00202: median nRF = 0.0000
# ✓ RF00203: median nRF = 0.1667
# ✓ RF00204: median nRF = 0.0000
# ✓ RF00205: median nRF = 0.0000
# ✓ RF00206: median nRF = 0.1250
# ✓ RF00207: median nRF = 0.3333
# ✓ RF00209: median nRF = 0.3000
# ✓ RF00210: median nRF = 0.2360
# ✓ RF00211: median nRF = 0.0000
# ✓ RF00212: median nRF = 0.0000
# ✓ RF00213: median nRF = 0.0625
# ✓ RF00214: median nRF = 0.2174
# ✓ RF00215: median nRF = 0.2500
# ✓ RF00216: median nRF = 0.5000
# ✓ RF00217: median nRF = 0.5556
# ✓ RF00218: median nRF = 0.0000
# ✓ RF00220: median nRF = 0.0000
# ✓ RF00222: median nRF = 0.0000
# ✓ RF00223: median nRF = 0.0000
# ✓ RF00224: median nRF = 0.0000
# ✓ RF00225: median nRF = 0.0000
# ✓ RF00226: median nRF = 0.0000
# ✓ RF00227: median nRF = 0.0000
# ✓ RF00228: median nRF = 0.2353
# ✓ RF00229: median nRF = 0.2247
# ✓ RF00230: median nRF = 0.4667
# ✓ RF00231: median nRF = 0.1000
# ✓ RF00232: median nRF = 0.5000
# ✓ RF00233: median nRF = 0.0769
# ✓ RF00234: median nRF = 0.4000
# ✓ RF00236: median nRF = 0.0000
# ✓ RF00237: median nRF = 0.4620
# ✓ RF00238: median nRF = 0.1034
# ✓ RF00239: median nRF = 0.5000
# ✓ RF00240: median nRF = 0.0909
# ✓ RF00241: median nRF = 0.2595
# ✓ RF00242: median nRF = 0.0000
# ✓ RF00243: median nRF = 0.0000
# ✓ RF00244: median nRF = 0.2951
# ✓ RF00245: median nRF = 0.4853
# ✓ RF00246: median nRF = 0.1897
# ✓ RF00247: median nRF = 0.2500
# ✓ RF00248: median nRF = 0.1957
# ✓ RF00249: median nRF = 0.1633
# ✓ RF00250: median nRF = 0.5476
# ✓ RF00251: median nRF = 0.3151
# ✓ RF00252: median nRF = 0.0833
# ✓ RF00253: median nRF = 0.1562
# ✓ RF00254: median nRF = 0.1818
# ✓ RF00255: median nRF = 0.3636
# ✓ RF00256: median nRF = 0.1224
# ✓ RF00257: median nRF = 0.1316
# ✓ RF00258: median nRF = 0.1667
# ✓ RF00260: median nRF = 0.1538
# ✓ RF00261: median nRF = 0.0000
# ✓ RF00263: median nRF = 0.3478
# ✓ RF00264: median nRF = 0.0000
# ✓ RF00265: median nRF = 0.0769
# ✓ RF00266: median nRF = 0.3500
# ✓ RF00267: median nRF = 0.0000
# ✓ RF00270: median nRF = 0.6250
# ✓ RF00271: median nRF = 0.5263
# ✓ RF00272: median nRF = 0.0000
# ✓ RF00273: median nRF = 0.1429
# ✓ RF00274: median nRF = 0.2500
# ✓ RF00275: median nRF = 0.5000
# ✓ RF00276: median nRF = 0.1176
# ✓ RF00278: median nRF = 0.3913
# ✓ RF00279: median nRF = 0.0000
# ✓ RF00280: median nRF = 0.5455
# ✓ RF00281: median nRF = 0.1765
# ✓ RF00282: median nRF = 0.2500
# ✓ RF00283: median nRF = 0.0625
# ✓ RF00284: median nRF = 0.4211
# ✓ RF00286: median nRF = 0.0526
# ✓ RF00287: median nRF = 0.2500
# ✓ RF00288: median nRF = 0.3529
# ✓ RF00289: median nRF = 0.2667
# ✓ RF00291: median nRF = 0.0000
# ✓ RF00292: median nRF = 0.0000
# ✓ RF00293: median nRF = 0.0000
# ✓ RF00294: median nRF = 0.0000
# ✓ RF00295: median nRF = 0.0000
# ✓ RF00296: median nRF = 0.1667
# ✓ RF00300: median nRF = 0.1250
# ✓ RF00301: median nRF = 0.0000
# ✓ RF00302: median nRF = 0.0909
# ✓ RF00303: median nRF = 0.0000
# ✓ RF00304: median nRF = 0.0000
# ✓ RF00305: median nRF = 0.0000
# ✓ RF00309: median nRF = 0.2105
# ✓ RF00311: median nRF = 0.0000
# ✓ RF00312: median nRF = 0.3333
# ✓ RF00315: median nRF = 0.0000
# ✓ RF00316: median nRF = 0.1250
# ✓ RF00317: median nRF = 0.0000
# ✓ RF00319: median nRF = 0.0000
# ✓ RF00321: median nRF = 0.0000
# ✓ RF00322: median nRF = 0.0000
# ✓ RF00324: median nRF = 0.2609
# ✓ RF00325: median nRF = 0.2121
# ✓ RF00326: median nRF = 0.0000
# ✓ RF00328: median nRF = 0.1250
# ✓ RF00329: median nRF = 0.0000
# ✓ RF00330: median nRF = 0.0000
# ✓ RF00332: median nRF = 0.0000
# ✓ RF00333: median nRF = 0.0000
# ✓ RF00334: median nRF = 0.0000
# ✓ RF00335: median nRF = 0.1892
# ✓ RF00336: median nRF = 0.0000
# ✓ RF00337: median nRF = 0.0000
# ✓ RF00338: median nRF = 0.0000
# ✓ RF00339: median nRF = 0.0000
# ✓ RF00340: median nRF = 0.0000
# ✓ RF00341: median nRF = 0.0000
# ✓ RF00343: median nRF = 0.0000
# ✓ RF00345: median nRF = 0.1111
# ✓ RF00348: median nRF = 0.2500
# ✓ RF00349: median nRF = 0.0000
# ✓ RF00350: median nRF = 0.0000
# ✓ RF00352: median nRF = 0.0000
# ✓ RF00353: median nRF = 0.0000
# ✓ RF00355: median nRF = 0.0000
# ✓ RF00356: median nRF = 0.0000
# ✓ RF00357: median nRF = 0.0400
# ✓ RF00358: median nRF = 0.0000
# ✓ RF00359: median nRF = 0.0000
# ✓ RF00360: median nRF = 0.0000
# ✓ RF00362: median nRF = 0.3846
# ✓ RF00364: median nRF = 0.0000
# ✓ RF00368: median nRF = 0.0000
# ✓ RF00369: median nRF = 0.0000
# ✓ RF00370: median nRF = 0.0000
# ✓ RF00371: median nRF = 0.0000
# ✓ RF00373: median nRF = 0.0149
# ✓ RF00374: median nRF = 0.2273
# ✓ RF00375: median nRF = 0.4766
# ✓ RF00376: median nRF = 0.5797
# ✓ RF00377: median nRF = 0.1818
# ✓ RF00378: median nRF = 0.4074
# ✓ RF00379: median nRF = 0.3883
# ✓ RF00380: median nRF = 0.2645
# ✓ RF00381: median nRF = 0.3000
# ✓ RF00382: median nRF = 0.0000
# ✓ RF00383: median nRF = 0.0000
# ✓ RF00384: median nRF = 0.2857
# ✓ RF00385: median nRF = 0.7143
# ✓ RF00386: median nRF = 0.5541
# ✓ RF00388: median nRF = 0.0000
# ✓ RF00389: median nRF = 0.3333
# ✓ RF00390: median nRF = 0.0000
# ✓ RF00391: median nRF = 0.3333
# ✓ RF00392: median nRF = 0.0000
# ✓ RF00393: median nRF = 0.0000
# ✓ RF00394: median nRF = 0.2500
# ✓ RF00396: median nRF = 0.2128
# ✓ RF00397: median nRF = 0.1333
# ✓ RF00398: median nRF = 0.4211
# ✓ RF00399: median nRF = 0.5000
# ✓ RF00400: median nRF = 0.4091
# ✓ RF00401: median nRF = 0.3571
# ✓ RF00402: median nRF = 0.2963
# ✓ RF00403: median nRF = 0.3333
# ✓ RF00404: median nRF = 0.6316
# ✓ RF00405: median nRF = 0.5652
# ✓ RF00406: median nRF = 0.0556
# ✓ RF00407: median nRF = 0.0000
# ✓ RF00408: median nRF = 0.5769
# ✓ RF00409: median nRF = 0.0714
# ✓ RF00410: median nRF = 0.0000
# ✓ RF00411: median nRF = 0.4545
# ✓ RF00413: median nRF = 0.1667
# ✓ RF00414: median nRF = 0.1429
# ✓ RF00415: median nRF = 0.0000
# ✓ RF00416: median nRF = 0.0556
# ✓ RF00417: median nRF = 0.0833
# ✓ RF00418: median nRF = 0.4118
# ✓ RF00419: median nRF = 0.3750
# ✓ RF00420: median nRF = 0.1364
# ✓ RF00421: median nRF = 0.1667
# ✓ RF00422: median nRF = 0.1500
# ✓ RF00423: median nRF = 0.0952
# ✓ RF00424: median nRF = 0.2941
# ✓ RF00425: median nRF = 0.4231
# ✓ RF00426: median nRF = 0.2105
# ✓ RF00427: median nRF = 0.0714
# ✓ RF00428: median nRF = 0.4545
# ✓ RF00429: median nRF = 0.3913
# ✓ RF00430: median nRF = 0.0000
# ✓ RF00431: median nRF = 0.3462
# ✓ RF00432: median nRF = 0.0000
# ✓ RF00433: median nRF = 0.0000
# ✓ RF00434: median nRF = 0.1429
# ✓ RF00435: median nRF = 0.0000
# ✓ RF00436: median nRF = 0.4091
# ✓ RF00437: median nRF = 0.0000
# ✓ RF00438: median nRF = 0.1739
# ✓ RF00439: median nRF = 0.1429
# ✓ RF00440: median nRF = 0.0000
# ✓ RF00441: median nRF = 0.0000
# ✓ RF00442: median nRF = 0.4227
# ✓ RF00443: median nRF = 0.5714
# ✓ RF00444: median nRF = 0.0000
# ✓ RF00445: median nRF = 0.0000
# ✓ RF00446: median nRF = 0.3415
# ✓ RF00447: median nRF = 0.0000
# ✓ RF00448: median nRF = 0.0000
# ✓ RF00449: median nRF = 0.0714
# ✓ RF00451: median nRF = 0.0625
# ✓ RF00452: median nRF = 0.0000
# ✓ RF00453: median nRF = 0.0000
# ✓ RF00454: median nRF = 0.4286
# ✓ RF00455: median nRF = 0.2295
# ✓ RF00456: median nRF = 0.4568
# ✓ RF00457: median nRF = 0.3750
# ✓ RF00458: median nRF = 0.0000
# ✓ RF00459: median nRF = 0.1667
# ✓ RF00460: median nRF = 0.3333
# ✓ RF00461: median nRF = 0.0000
# ✓ RF00462: median nRF = 0.0000
# ✓ RF00463: median nRF = 0.0000
# ✓ RF00464: median nRF = 0.0000
# ✓ RF00467: median nRF = 0.2105
# ✓ RF00468: median nRF = 0.2308
# ✓ RF00470: median nRF = 0.3333
# ✓ RF00471: median nRF = 0.0000
# ✓ RF00474: median nRF = 0.0000
# ✓ RF00475: median nRF = 0.0000
# ✓ RF00477: median nRF = 0.0000
# ✓ RF00478: median nRF = 0.3077
# ✓ RF00479: median nRF = 0.0000
# ✓ RF00480: median nRF = 0.7222
# ✓ RF00481: median nRF = 0.1250
# ✓ RF00482: median nRF = 0.0000
# ✓ RF00483: median nRF = 0.1667
# ✓ RF00484: median nRF = 0.0000
# ✓ RF00485: median nRF = 0.1951
# ✓ RF00486: median nRF = 0.0000
# ✓ RF00487: median nRF = 0.0000
# ✓ RF00488: median nRF = 0.0000
# ✓ RF00489: median nRF = 0.7143
# ✓ RF00490: median nRF = 0.2308
# ✓ RF00492: median nRF = 0.0000
# ✓ RF00493: median nRF = 0.1111
# ✓ RF00494: median nRF = 0.4231
# ✓ RF00495: median nRF = 0.0000
# ✓ RF00499: median nRF = 0.0000
# ✓ RF00501: median nRF = 0.1250
# ✓ RF00503: median nRF = 0.0000
# ✓ RF00504: median nRF = 0.2927
# ✓ RF00505: median nRF = 0.3333
# ✓ RF00506: median nRF = 0.0000
# ✓ RF00507: median nRF = 0.1364
# ✓ RF00510: median nRF = 0.1000
# ✓ RF00511: median nRF = 0.0000
# ✓ RF00512: median nRF = 0.0000
# ✓ RF00513: median nRF = 0.0000
# ✓ RF00514: median nRF = 0.0345
# ✓ RF00515: median nRF = 0.0667
# ✓ RF00517: median nRF = 0.6716
# ✓ RF00518: median nRF = 0.0000
# ✓ RF00519: median nRF = 0.4524
# ✓ RF00520: median nRF = 0.0000
# ✓ RF00521: median nRF = 0.0541
# ✓ RF00522: median nRF = 0.3846
# ✓ RF00523: median nRF = 0.6806
# ✓ RF00524: median nRF = 0.0000
# ✓ RF00525: median nRF = 0.3303
# ✓ RF00526: median nRF = 0.0000
# ✓ RF00527: median nRF = 0.0000
# ✓ RF00528: median nRF = 0.3750
# ✓ RF00529: median nRF = 0.0000
# ✓ RF00530: median nRF = 0.2667
# ✓ RF00531: median nRF = 0.0833
# ✓ RF00532: median nRF = 0.3889
# ✓ RF00533: median nRF = 0.0000
# ✓ RF00534: median nRF = 0.0000
# ✓ RF00535: median nRF = 0.0000
# ✓ RF00536: median nRF = 0.3750
# ✓ RF00537: median nRF = 0.0000
# ✓ RF00538: median nRF = 0.5217
# ✓ RF00539: median nRF = 0.0000
# ✓ RF00540: median nRF = 0.0769
# ✓ RF00541: median nRF = 0.0000
# ✓ RF00542: median nRF = 0.1667
# ✓ RF00543: median nRF = 0.0000
# ✓ RF00544: median nRF = 0.0000
# ✓ RF00545: median nRF = 0.0000
# ✓ RF00546: median nRF = 0.0000
# ✓ RF00547: median nRF = 0.0000
# ✓ RF00548: median nRF = 0.2090
# ✓ RF00549: median nRF = 0.1429
# ✓ RF00550: median nRF = 0.1628
# ✓ RF00551: median nRF = 0.1667
# ✓ RF00552: median nRF = 0.1333
# ✓ RF00553: median nRF = 0.0800
# ✓ RF00554: median nRF = 0.4286
# ✓ RF00555: median nRF = 0.3043
# ✓ RF00556: median nRF = 0.1429
# ✓ RF00557: median nRF = 0.4824
# ✓ RF00558: median nRF = 0.0500
# ✓ RF00559: median nRF = 0.0857
# ✓ RF00560: median nRF = 0.3947
# ✓ RF00561: median nRF = 0.4400
# ✓ RF00562: median nRF = 0.1111
# ✓ RF00563: median nRF = 0.5000
# ✓ RF00564: median nRF = 0.1500
# ✓ RF00565: median nRF = 0.1000
# ✓ RF00566: median nRF = 0.1923
# ✓ RF00567: median nRF = 0.0625
# ✓ RF00568: median nRF = 0.4932
# ✓ RF00569: median nRF = 0.4211
# ✓ RF00570: median nRF = 0.5000
# ✓ RF00572: median nRF = 0.2353
# ✓ RF00573: median nRF = 0.0833
# ✓ RF00574: median nRF = 0.2500
# ✓ RF00575: median nRF = 0.4444
# ✓ RF00576: median nRF = 0.0000
# ✓ RF00577: median nRF = 0.1538
# ✓ RF00578: median nRF = 0.5333
# ✓ RF00579: median nRF = 0.6000
# ✓ RF00580: median nRF = 0.1429
# ✓ RF00581: median nRF = 0.0000
# ✓ RF00582: median nRF = 0.3158
# ✓ RF00584: median nRF = 0.3333
# ✓ RF00586: median nRF = 0.0000
# ✓ RF00588: median nRF = 0.2941
# ✓ RF00591: median nRF = 0.0556
# ✓ RF00593: median nRF = 0.2222
# ✓ RF00594: median nRF = 0.0000
# ✓ RF00598: median nRF = 0.5789
# ✓ RF00599: median nRF = 0.0000
# ✓ RF00600: median nRF = 0.3636
# ✓ RF00601: median nRF = 0.0000
# ✓ RF00602: median nRF = 0.6667
# ✓ RF00603: median nRF = 0.5833
# ✓ RF00604: median nRF = 0.0938
# ✓ RF00606: median nRF = 0.1538
# ✓ RF00607: median nRF = 0.1667
# ✓ RF00608: median nRF = 0.5500
# ✓ RF00609: median nRF = 0.1739
# ✓ RF00610: median nRF = 0.1538
# ✓ RF00611: median nRF = 0.5000
# ✓ RF00612: median nRF = 0.0000
# ✓ RF00613: median nRF = 0.0556
# ✓ RF00614: median nRF = 0.5806
# ✓ RF00615: median nRF = 0.3333
# ✓ RF00616: median nRF = 0.0000
# ✓ RF00617: median nRF = 0.4727
# ✓ RF00618: median nRF = 0.2000
# ✓ RF00619: median nRF = 0.3393
# ✓ RF00620: median nRF = 0.4314
# ✓ RF00621: median nRF = 0.0000
# ✓ RF00622: median nRF = 0.2727
# ✓ RF00623: median nRF = 0.0000
# ✓ RF00624: median nRF = 0.3846
# ✓ RF00625: median nRF = 0.0000
# ✓ RF00627: median nRF = 0.1667
# ✓ RF00628: median nRF = 0.0417
# ✓ RF00629: median nRF = 0.0909
# ✓ RF00630: median nRF = 0.0435
# ✓ RF00634: median nRF = 0.5676
# ✓ RF00636: median nRF = 0.1905
# ✓ RF00637: median nRF = 0.2581
# ✓ RF00638: median nRF = 0.1111
# ✓ RF00639: median nRF = 0.2201
# ✓ RF00641: median nRF = 0.1489
# ✓ RF00642: median nRF = 0.3333
# ✓ RF00643: median nRF = 0.2692
# ✓ RF00644: median nRF = 0.1692
# ✓ RF00645: median nRF = 0.4167
# ✓ RF00646: median nRF = 0.3488
# ✓ RF00648: median nRF = 0.0909
# ✓ RF00649: median nRF = 0.0541
# ✓ RF00650: median nRF = 0.3095
# ✓ RF00651: median nRF = 0.4643
# ✓ RF00653: median nRF = 0.0000
# ✓ RF00654: median nRF = 0.2326
# ✓ RF00655: median nRF = 0.0625
# ✓ RF00656: median nRF = 0.2121
# ✓ RF00657: median nRF = 0.3019
# ✓ RF00658: median nRF = 0.1739
# ✓ RF00659: median nRF = 0.1724
# ✓ RF00660: median nRF = 0.3000
# ✓ RF00661: median nRF = 0.2881
# ✓ RF00662: median nRF = 0.1026
# ✓ RF00663: median nRF = 0.2174
# ✓ RF00664: median nRF = 0.3810
# ✓ RF00665: median nRF = 0.2692
# ✓ RF00666: median nRF = 0.2222
# ✓ RF00667: median nRF = 0.5172
# ✓ RF00668: median nRF = 0.2927
# ✓ RF00669: median nRF = 0.3125
# ✓ RF00670: median nRF = 0.0000
# ✓ RF00671: median nRF = 0.1714
# ✓ RF00672: median nRF = 0.2549
# ✓ RF00673: median nRF = 0.4545
# ✓ RF00674: median nRF = 0.1000
# ✓ RF00675: median nRF = 0.4375
# ✓ RF00676: median nRF = 1.0000
# ✓ RF00677: median nRF = 0.0000
# ✓ RF00678: median nRF = 0.3750
# ✓ RF00679: median nRF = 0.2174
# ✓ RF00680: median nRF = 0.2500
# ✓ RF00681: median nRF = 0.3333
# ✓ RF00682: median nRF = 0.5385
# ✓ RF00683: median nRF = 0.6316
# ✓ RF00684: median nRF = 0.2500
# ✓ RF00685: median nRF = 0.4048
# ✓ RF00686: median nRF = 0.2143
# ✓ RF00687: median nRF = 0.2000
# ✓ RF00688: median nRF = 0.0000
# ✓ RF00689: median nRF = 0.0833
# ✓ RF00690: median nRF = 0.0000
# ✓ RF00691: median nRF = 0.0333
# ✓ RF00692: median nRF = 0.0000
# ✓ RF00693: median nRF = 0.2632
# ✓ RF00694: median nRF = 0.2821
# ✓ RF00695: median nRF = 0.0000
# ✓ RF00696: median nRF = 0.3077
# ✓ RF00697: median nRF = 0.3333
# ✓ RF00698: median nRF = 0.1875
# ✓ RF00699: median nRF = 0.3750
# ✓ RF00700: median nRF = 0.1765
# ✓ RF00701: median nRF = 0.2500
# ✓ RF00702: median nRF = 0.3043
# ✓ RF00703: median nRF = 0.0625
# ✓ RF00704: median nRF = 0.0000
# ✓ RF00705: median nRF = 0.2500
# ✓ RF00706: median nRF = 0.2222
# ✓ RF00707: median nRF = 0.0000
# ✓ RF00708: median nRF = 0.3333
# ✓ RF00709: median nRF = 0.4706
# ✓ RF00710: median nRF = 0.0000
# ✓ RF00711: median nRF = 0.3714
# ✓ RF00712: median nRF = 0.0556
# ✓ RF00713: median nRF = 0.0000
# ✓ RF00714: median nRF = 0.1176
# ✓ RF00715: median nRF = 0.0769
# ✓ RF00716: median nRF = 0.0000
# ✓ RF00717: median nRF = 0.1304
# ✓ RF00718: median nRF = 0.0000
# ✓ RF00719: median nRF = 0.0000
# ✓ RF00720: median nRF = 0.4444
# ✓ RF00721: median nRF = 0.0000
# ✓ RF00722: median nRF = 0.1250
# ✓ RF00723: median nRF = 0.0000
# ✓ RF00724: median nRF = 0.0556
# ✓ RF00725: median nRF = 0.0000
# ✓ RF00726: median nRF = 0.3158
# ✓ RF00727: median nRF = 0.4444
# ✓ RF00728: median nRF = 0.0000
# ✓ RF00729: median nRF = 0.1579
# ✓ RF00730: median nRF = 0.0625
# ✓ RF00731: median nRF = 0.2632
# ✓ RF00732: median nRF = 0.0625
# ✓ RF00733: median nRF = 0.0000
# ✓ RF00734: median nRF = 0.0000
# ✓ RF00735: median nRF = 0.2727
# ✓ RF00736: median nRF = 0.1562
# ✓ RF00737: median nRF = 0.1250
# ✓ RF00740: median nRF = 0.0000
# ✓ RF00741: median nRF = 0.0000
# ✓ RF00742: median nRF = 0.2188
# ✓ RF00743: median nRF = 0.1538
# ✓ RF00744: median nRF = 0.1667
# ✓ RF00745: median nRF = 0.1818
# ✓ RF00746: median nRF = 0.2000
# ✓ RF00747: median nRF = 0.1250
# ✓ RF00748: median nRF = 0.0000
# ✓ RF00749: median nRF = 0.0526
# ✓ RF00750: median nRF = 0.1111
# ✓ RF00751: median nRF = 0.2500
# ✓ RF00752: median nRF = 0.4167
# ✓ RF00753: median nRF = 0.1818
# ✓ RF00754: median nRF = 0.2857
# ✓ RF00755: median nRF = 0.2000
# ✓ RF00756: median nRF = 0.6667
# ✓ RF00757: median nRF = 0.1579
# ✓ RF00758: median nRF = 0.0000
# ✓ RF00760: median nRF = 0.0000
# ✓ RF00761: median nRF = 0.2222
# ✓ RF00762: median nRF = 0.2500
# ✓ RF00763: median nRF = 0.0000
# ✓ RF00764: median nRF = 0.3333
# ✓ RF00765: median nRF = 0.0000
# ✓ RF00766: median nRF = 0.0000
# ✓ RF00767: median nRF = 0.1333
# ✓ RF00769: median nRF = 0.5000
# ✓ RF00770: median nRF = 0.2500
# ✓ RF00771: median nRF = 0.4286
# ✓ RF00772: median nRF = 0.3333
# ✓ RF00773: median nRF = 0.0000
# ✓ RF00774: median nRF = 0.0000
# ✓ RF00775: median nRF = 0.0000
# ✓ RF00777: median nRF = 0.2000
# ✓ RF00778: median nRF = 0.0000
# ✓ RF00779: median nRF = 0.0000
# ✓ RF00781: median nRF = 0.8000
# ✓ RF00782: median nRF = 0.5758
# ✓ RF00783: median nRF = 0.3333
# ✓ RF00784: median nRF = 0.0000
# ✓ RF00785: median nRF = 0.0000
# ✓ RF00786: median nRF = 0.6667
# ✓ RF00787: median nRF = 0.1250
# ✓ RF00788: median nRF = 0.0000
# ✓ RF00789: median nRF = 0.1818
# ✓ RF00791: median nRF = 0.5000
# ✓ RF00792: median nRF = 0.0000
# ✓ RF00793: median nRF = 0.1818
# ✓ RF00795: median nRF = 0.0000
# ✓ RF00796: median nRF = 0.0000
# ✓ RF00797: median nRF = 0.0000
# ✓ RF00798: median nRF = 0.0000
# ✓ RF00801: median nRF = 0.2000
# ✓ RF00803: median nRF = 0.1538
# ✓ RF00806: median nRF = 0.0000
# ✓ RF00807: median nRF = 0.1429
# ✓ RF00808: median nRF = 0.0000
# ✓ RF00809: median nRF = 0.0000
# ✓ RF00810: median nRF = 0.0000
# ✓ RF00811: median nRF = 0.0000
# ✓ RF00812: median nRF = 0.0000
# ✓ RF00813: median nRF = 0.0714
# ✓ RF00814: median nRF = 0.0667
# ✓ RF00815: median nRF = 0.0000
# ✓ RF00816: median nRF = 0.0000
# ✓ RF00817: median nRF = 0.0000
# ✓ RF00818: median nRF = 0.1667
# ✓ RF00819: median nRF = 0.0000
# ✓ RF00822: median nRF = 0.0000
# ✓ RF00824: median nRF = 0.0000
# ✓ RF00825: median nRF = 0.0714
# ✓ RF00827: median nRF = 0.0000
# ✓ RF00828: median nRF = 0.0000
# ✓ RF00829: median nRF = 0.0000
# ✓ RF00830: median nRF = 0.0000
# ✓ RF00831: median nRF = 0.0000
# ✓ RF00832: median nRF = 0.1250
# ✓ RF00835: median nRF = 0.0000
# ✓ RF00836: median nRF = 0.0000
# ✓ RF00837: median nRF = 0.0000
# ✓ RF00838: median nRF = 0.2105
# ✓ RF00839: median nRF = 0.0000
# ✓ RF00840: median nRF = 0.1000
# ✓ RF00841: median nRF = 0.0000
# ✓ RF00842: median nRF = 0.0000
# ✓ RF00843: median nRF = 0.5000
# ✓ RF00844: median nRF = 0.0870
# ✓ RF00845: median nRF = 0.0000
# ✓ RF00846: median nRF = 0.0000
# ✓ RF00847: median nRF = 0.0000
# ✓ RF00848: median nRF = 0.0000
# ✓ RF00849: median nRF = 0.0000
# ✓ RF00852: median nRF = 0.0000
# ✓ RF00853: median nRF = 0.0000
# ✓ RF00854: median nRF = 0.0000
# ✓ RF00855: median nRF = 0.0000
# ✓ RF00856: median nRF = 0.0000
# ✓ RF00857: median nRF = 0.0000
# ✓ RF00858: median nRF = 0.0000
# ✓ RF00859: median nRF = 0.0000
# ✓ RF00861: median nRF = 0.2000
# ✓ RF00862: median nRF = 0.2000
# ✓ RF00865: median nRF = 0.0000
# ✓ RF00870: median nRF = 0.0000
# ✓ RF00872: median nRF = 0.2000
# ✓ RF00873: median nRF = 0.2500
# ✓ RF00877: median nRF = 0.0000
# ✓ RF00878: median nRF = 0.0000
# ✓ RF00879: median nRF = 0.3333
# ✓ RF00885: median nRF = 0.0000
# ✓ RF00886: median nRF = 0.1481
# ✓ RF00887: median nRF = 0.5000
# ✓ RF00888: median nRF = 0.0000
# ✓ RF00890: median nRF = 0.0000
# ✓ RF00891: median nRF = 0.0000
# ✓ RF00892: median nRF = 0.1364
# ✓ RF00894: median nRF = 0.0000
# ✓ RF00897: median nRF = 0.0000
# ✓ RF00900: median nRF = 0.0000
# ✓ RF00901: median nRF = 0.0000
# ✓ RF00906: median nRF = 0.0000
# ✓ RF00910: median nRF = 0.0000
# ✓ RF00911: median nRF = 0.0000
# ✓ RF00912: median nRF = 0.2500
# ✓ RF00915: median nRF = 0.0000
# ✓ RF00917: median nRF = 0.0000
# ✓ RF00918: median nRF = 0.0000
# ✓ RF00919: median nRF = 0.0000
# ✓ RF00920: median nRF = 0.0625
# ✓ RF00921: median nRF = 0.0000
# ✓ RF00927: median nRF = 0.2857
# ✓ RF00928: median nRF = 0.0000
# ✓ RF00929: median nRF = 0.3333
# ✓ RF00933: median nRF = 0.1250
# ✓ RF00935: median nRF = 0.0000
# ✓ RF00936: median nRF = 0.0000
# ✓ RF00937: median nRF = 0.2000
# ✓ RF00939: median nRF = 0.2857
# ✓ RF00942: median nRF = 0.2000
# ✓ RF00943: median nRF = 0.3333
# ✓ RF00947: median nRF = 0.5833
# ✓ RF00948: median nRF = 0.0000
# ✓ RF00950: median nRF = 0.0833
# ✓ RF00951: median nRF = 0.4762
# ✓ RF00952: median nRF = 0.2000
# ✓ RF00954: median nRF = 0.3333
# ✓ RF00955: median nRF = 0.0000
# ✓ RF00957: median nRF = 0.0000
# ✓ RF00958: median nRF = 0.0000
# ✓ RF00961: median nRF = 0.0000
# ✓ RF00962: median nRF = 0.0000
# ✓ RF00964: median nRF = 1.0000
# ✓ RF00965: median nRF = 0.0000
# ✓ RF00966: median nRF = 0.1429
# ✓ RF00969: median nRF = 0.0000
# ✓ RF00972: median nRF = 0.0000
# ✓ RF00973: median nRF = 0.0000
# ✓ RF00976: median nRF = 0.0000
# ✓ RF00981: median nRF = 0.0000
# ✓ RF00984: median nRF = 1.0000
# ✓ RF00985: median nRF = 1.0000
# ✓ RF00986: median nRF = 0.0000
# ✓ RF00987: median nRF = 0.0000
# ✓ RF00989: median nRF = 0.3333
# ✓ RF00991: median nRF = 0.2500
# ✓ RF00992: median nRF = 0.0000
# ✓ RF00994: median nRF = 0.0000
# ✓ RF00995: median nRF = 0.0000
# ✓ RF00996: median nRF = 0.5000
# ✓ RF00997: median nRF = 0.0000
# ✓ RF00998: median nRF = 0.0000
# ✓ RF01000: median nRF = 0.0000
# ✓ RF01001: median nRF = 0.0000
# ✓ RF01002: median nRF = 0.0000
# ✓ RF01004: median nRF = 0.0000
# ✓ RF01006: median nRF = 0.0000
# ✓ RF01007: median nRF = 0.0000
# ✓ RF01010: median nRF = 0.0000
# ✓ RF01011: median nRF = 0.0000
# ✓ RF01012: median nRF = 0.2500
# ✓ RF01013: median nRF = 0.0000
# ✓ RF01014: median nRF = 0.0000
# ✓ RF01015: median nRF = 0.0000
# ✓ RF01016: median nRF = 0.1538
# ✓ RF01018: median nRF = 0.0000
# ✓ RF01019: median nRF = 0.0000
# ✓ RF01023: median nRF = 0.0000
# ✓ RF01024: median nRF = 0.0000
# ✓ RF01025: median nRF = 0.0000
# ✓ RF01026: median nRF = 0.0769
# ✓ RF01027: median nRF = 0.0000
# ✓ RF01028: median nRF = 0.0000
# ✓ RF01032: median nRF = 0.0000
# ✓ RF01033: median nRF = 0.3333
# ✓ RF01034: median nRF = 0.0000
# ✓ RF01038: median nRF = 0.0000
# ✓ RF01039: median nRF = 1.0000
# ✓ RF01041: median nRF = 0.0000
# ✓ RF01042: median nRF = 0.0000
# ✓ RF01043: median nRF = 0.0000
# ✓ RF01044: median nRF = 0.1667
# ✓ RF01045: median nRF = 0.1429
# ✓ RF01046: median nRF = 0.5000
# ✓ RF01047: median nRF = 0.0000
# ✓ RF01050: median nRF = 0.0000
# ✓ RF01051: median nRF = 0.5575
# ✓ RF01052: median nRF = 0.0000
# ✓ RF01054: median nRF = 0.1000
# ✓ RF01055: median nRF = 0.4040
# ✓ RF01056: median nRF = 0.0000
# ✓ RF01057: median nRF = 0.6122
# ✓ RF01059: median nRF = 0.0000
# ✓ RF01061: median nRF = 0.1250
# ✓ RF01065: median nRF = 0.0625
# ✓ RF01066: median nRF = 0.1333
# ✓ RF01067: median nRF = 0.6437
# ✓ RF01068: median nRF = 0.7059
# ✓ RF01069: median nRF = 0.0000
# ✓ RF01070: median nRF = 0.0312
# ✓ RF01071: median nRF = 0.0000
# ✓ RF01072: median nRF = 0.5238
# ✓ RF01073: median nRF = 0.0000
# ✓ RF01074: median nRF = 0.0000
# ✓ RF01077: median nRF = 0.0000
# ✓ RF01080: median nRF = 0.0000
# ✓ RF01084: median nRF = 0.0000
# ✓ RF01087: median nRF = 0.0000
# ✓ RF01089: median nRF = 0.7500
# ✓ RF01090: median nRF = 0.5000
# ✓ RF01093: median nRF = 0.1111
# ✓ RF01097: median nRF = 0.0000
# ✓ RF01099: median nRF = 0.5862
# ✓ RF01116: median nRF = 0.4118
# ✓ RF01117: median nRF = 0.0000
# ✓ RF01130: median nRF = 0.0000
# ✓ RF01140: median nRF = 0.0000
# ✓ RF01156: median nRF = 0.0000
# ✓ RF01157: median nRF = 0.0000
# ✓ RF01158: median nRF = 0.0000
# ✓ RF01162: median nRF = 1.0000
# ✓ RF01164: median nRF = 0.5000
# ✓ RF01165: median nRF = 1.0000
# ✓ RF01167: median nRF = 0.0000
# ✓ RF01168: median nRF = 0.6667
# ✓ RF01169: median nRF = 0.6000
# ✓ RF01170: median nRF = 0.0000
# ✓ RF01173: median nRF = 0.6000
# ✓ RF01175: median nRF = 0.0000
# ✓ RF01176: median nRF = 0.0000
# ✓ RF01178: median nRF = 0.0556
# ✓ RF01179: median nRF = 0.0000
# ✓ RF01182: median nRF = 0.3125
# ✓ RF01183: median nRF = 0.1429
# ✓ RF01186: median nRF = 0.1000
# ✓ RF01189: median nRF = 0.0000
# ✓ RF01191: median nRF = 0.1304
# ✓ RF01192: median nRF = 0.4118
# ✓ RF01193: median nRF = 0.0000
# ✓ RF01196: median nRF = 0.0000
# ✓ RF01197: median nRF = 0.0000
# ✓ RF01198: median nRF = 0.2500
# ✓ RF01200: median nRF = 0.0769
# ✓ RF01202: median nRF = 0.0000
# ✓ RF01203: median nRF = 0.1429
# ✓ RF01206: median nRF = 0.0000
# ✓ RF01208: median nRF = 0.0000
# ✓ RF01209: median nRF = 0.0000
# ✓ RF01211: median nRF = 0.4000
# ✓ RF01213: median nRF = 0.0000
# ✓ RF01214: median nRF = 0.0714
# ✓ RF01215: median nRF = 0.0000
# ✓ RF01216: median nRF = 0.0000
# ✓ RF01218: median nRF = 0.0000
# ✓ RF01219: median nRF = 0.0000
# ✓ RF01220: median nRF = 0.0000
# ✓ RF01221: median nRF = 0.0000
# ✓ RF01224: median nRF = 0.0000
# ✓ RF01225: median nRF = 0.0370
# ✓ RF01226: median nRF = 0.0000
# ✓ RF01227: median nRF = 0.0000
# ✓ RF01228: median nRF = 0.0000
# ✓ RF01229: median nRF = 0.1200
# ✓ RF01230: median nRF = 0.0000
# ✓ RF01231: median nRF = 0.0000
# ✓ RF01232: median nRF = 0.5000
# ✓ RF01233: median nRF = 0.3913
# ✓ RF01234: median nRF = 0.1765
# ✓ RF01235: median nRF = 0.0000
# ✓ RF01237: median nRF = 0.0000
# ✓ RF01238: median nRF = 0.0000
# ✓ RF01239: median nRF = 0.0000
# ✓ RF01240: median nRF = 0.0000
# ✓ RF01241: median nRF = 0.4400
# ✓ RF01242: median nRF = 0.0000
# ✓ RF01243: median nRF = 0.0000
# ✓ RF01244: median nRF = 0.0000
# ✓ RF01245: median nRF = 0.0000
# ✓ RF01247: median nRF = 0.1250
# ✓ RF01248: median nRF = 0.0000
# ✓ RF01249: median nRF = 0.0000
# ✓ RF01250: median nRF = 0.0000
# ✓ RF01251: median nRF = 0.0000
# ✓ RF01252: median nRF = 0.0000
# ✓ RF01253: median nRF = 0.0000
# ✓ RF01254: median nRF = 0.0000
# ✓ RF01255: median nRF = 0.0000
# ✓ RF01256: median nRF = 0.0000
# ✓ RF01257: median nRF = 0.0000
# ✓ RF01258: median nRF = 0.0000
# ✓ RF01259: median nRF = 0.0000
# ✓ RF01260: median nRF = 0.0000
# ✓ RF01261: median nRF = 0.0000
# ✓ RF01262: median nRF = 0.0000
# ✓ RF01263: median nRF = 0.0000
# ✓ RF01264: median nRF = 0.0000
# ✓ RF01265: median nRF = 0.0000
# ✓ RF01267: median nRF = 0.0000
# ✓ RF01268: median nRF = 0.3750
# ✓ RF01269: median nRF = 0.0000
# ✓ RF01270: median nRF = 0.0000
# ✓ RF01271: median nRF = 0.0000
# ✓ RF01272: median nRF = 0.0000
# ✓ RF01273: median nRF = 1.0000
# ✓ RF01274: median nRF = 0.0000
# ✓ RF01275: median nRF = 0.0000
# ✓ RF01277: median nRF = 0.1200
# ✓ RF01278: median nRF = 0.2500
# ✓ RF01279: median nRF = 0.0000
# ✓ RF01280: median nRF = 0.0000
# ✓ RF01281: median nRF = 0.0000
# ✓ RF01283: median nRF = 0.0000
# ✓ RF01284: median nRF = 0.0000
# ✓ RF01285: median nRF = 0.0000
# ✓ RF01286: median nRF = 0.0000
# ✓ RF01287: median nRF = 0.0000
# ✓ RF01288: median nRF = 0.0000
# ✓ RF01290: median nRF = 0.0526
# ✓ RF01291: median nRF = 0.5882
# ✓ RF01292: median nRF = 0.0000
# ✓ RF01294: median nRF = 0.0769
# ✓ RF01295: median nRF = 0.0667
# ✓ RF01296: median nRF = 0.0556
# ✓ RF01299: median nRF = 0.3571
# ✓ RF01300: median nRF = 0.0000
# ✓ RF01302: median nRF = 0.1111
# ✓ RF01304: median nRF = 0.2500
# ✓ RF01307: median nRF = 0.0000
# ✓ RF01308: median nRF = 0.5000
# ✓ RF01309: median nRF = 0.0000
# ✓ RF01313: median nRF = 0.0000
# ✓ RF01314: median nRF = 0.0000
# ✓ RF01315: median nRF = 0.4375
# ✓ RF01316: median nRF = 0.4118
# ✓ RF01317: median nRF = 0.6667
# ✓ RF01318: median nRF = 0.1111
# ✓ RF01319: median nRF = 0.3333
# ✓ RF01320: median nRF = 0.2857
# ✓ RF01321: median nRF = 0.0000
# ✓ RF01322: median nRF = 0.0000
# ✓ RF01323: median nRF = 0.0000
# ✓ RF01324: median nRF = 0.0000
# ✓ RF01325: median nRF = 0.0000
# ✓ RF01326: median nRF = 0.0000
# ✓ RF01332: median nRF = 0.0000
# ✓ RF01335: median nRF = 0.5000
# ✓ RF01337: median nRF = 0.0000
# ✓ RF01338: median nRF = 0.0000
# ✓ RF01344: median nRF = 0.5000
# ✓ RF01348: median nRF = 0.0000
# ✓ RF01379: median nRF = 0.0000
# ✓ RF01380: median nRF = 0.5000
# ✓ RF01381: median nRF = 0.4444
# ✓ RF01382: median nRF = 0.3750
# ✓ RF01383: median nRF = 0.0000
# ✓ RF01384: median nRF = 0.0000
# ✓ RF01385: median nRF = 0.0000
# ✓ RF01387: median nRF = 0.0000
# ✓ RF01390: median nRF = 0.0000
# ✓ RF01391: median nRF = 0.0000
# ✓ RF01392: median nRF = 0.0769
# ✓ RF01393: median nRF = 0.0000
# ✓ RF01394: median nRF = 0.4490
# ✓ RF01395: median nRF = 0.0000
# ✓ RF01396: median nRF = 0.0000
# ✓ RF01397: median nRF = 0.0000
# ✓ RF01398: median nRF = 0.2500
# ✓ RF01399: median nRF = 0.6667
# ✓ RF01400: median nRF = 0.2500
# ✓ RF01401: median nRF = 0.7778
# ✓ RF01402: median nRF = 0.0000
# ✓ RF01405: median nRF = 0.2632
# ✓ RF01406: median nRF = 0.4000
# ✓ RF01407: median nRF = 0.6000
# ✓ RF01408: median nRF = 0.0000
# ✓ RF01410: median nRF = 0.1500
# ✓ RF01411: median nRF = 0.0000
# ✓ RF01412: median nRF = 0.0000
# ✓ RF01413: median nRF = 0.1538
# ✓ RF01414: median nRF = 0.3689
# ✓ RF01415: median nRF = 0.2778
# ✓ RF01417: median nRF = 0.4000
# ✓ RF01418: median nRF = 0.5769
# ✓ RF01419: median nRF = 0.3967
# ✓ RF01420: median nRF = 0.0000
# ✓ RF01421: median nRF = 0.2381
# ✓ RF01422: median nRF = 0.0000
# ✓ RF01423: median nRF = 0.0000
# ✓ RF01426: median nRF = 0.0000
# ✓ RF01428: median nRF = 0.0000
# ✓ RF01430: median nRF = 0.0000
# ✓ RF01431: median nRF = 0.0000
# ✓ RF01433: median nRF = 0.0000
# ✓ RF01452: median nRF = 0.0000
# ✓ RF01455: median nRF = 0.6429
# ✓ RF01456: median nRF = 0.0000
# ✓ RF01457: median nRF = 0.5000
# ✓ RF01458: median nRF = 0.0000
# ✓ RF01459: median nRF = 0.0000
# ✓ RF01461: median nRF = 0.0000
# ✓ RF01462: median nRF = 0.0000
# ✓ RF01464: median nRF = 0.0000
# ✓ RF01466: median nRF = 0.5000
# ✓ RF01468: median nRF = 0.0000
# ✓ RF01470: median nRF = 0.0000
# ✓ RF01471: median nRF = 0.0000
# ✓ RF01472: median nRF = 0.0000
# ✓ RF01473: median nRF = 0.0000
# ✓ RF01474: median nRF = 0.0000
# ✓ RF01475: median nRF = 0.0000
# ✓ RF01476: median nRF = 0.0000
# ✓ RF01477: median nRF = 0.0000
# ✓ RF01478: median nRF = 0.0000
# ✓ RF01480: median nRF = 0.0000
# ✓ RF01481: median nRF = 0.0000
# ✓ RF01482: median nRF = 0.0000
# ✓ RF01483: median nRF = 0.0000
# ✓ RF01484: median nRF = 0.0000
# ✓ RF01487: median nRF = 0.0000
# ✓ RF01488: median nRF = 0.0000
# ✓ RF01489: median nRF = 1.0000
# ✓ RF01490: median nRF = 0.2000
# ✓ RF01491: median nRF = 0.0000
# ✓ RF01492: median nRF = 0.3529
# ✓ RF01493: median nRF = 0.0000
# ✓ RF01494: median nRF = 0.0000
# ✓ RF01495: median nRF = 0.0000
# ✓ RF01496: median nRF = 0.0625
# ✓ RF01497: median nRF = 0.0000
# ✓ RF01502: median nRF = 0.0455
# ✓ RF01504: median nRF = 0.0000
# ✓ RF01508: median nRF = 0.0000
# ✓ RF01510: median nRF = 0.0000
# ✓ RF01512: median nRF = 0.0000
# ✓ RF01517: median nRF = 0.0000
# ✓ RF01518: median nRF = 0.0000
# ✓ RF01522: median nRF = 0.0000
# ✓ RF01523: median nRF = 0.0000
# ✓ RF01524: median nRF = 0.0000
# ✓ RF01525: median nRF = 0.0000
# ✓ RF01531: median nRF = 0.0000
# ✓ RF01532: median nRF = 0.0000
# ✓ RF01535: median nRF = 0.0000
# ✓ RF01536: median nRF = 0.2500
# ✓ RF01537: median nRF = 0.0000
# ✓ RF01538: median nRF = 0.0000
# ✓ RF01539: median nRF = 0.0000
# ✓ RF01540: median nRF = 0.0000
# ✓ RF01543: median nRF = 0.0000
# ✓ RF01544: median nRF = 0.0000
# ✓ RF01546: median nRF = 0.0000
# ✓ RF01547: median nRF = 0.0000
# ✓ RF01548: median nRF = 0.0000
# ✓ RF01549: median nRF = 0.0000
# ✓ RF01550: median nRF = 0.0000
# ✓ RF01552: median nRF = 0.5000
# ✓ RF01554: median nRF = 0.0000
# ✓ RF01555: median nRF = 0.0000
# ✓ RF01557: median nRF = 0.0000
# ✓ RF01558: median nRF = 0.0000
# ✓ RF01581: median nRF = 0.2143
# ✓ RF01585: median nRF = 0.0000
# ✓ RF01587: median nRF = 1.0000
# ✓ RF01588: median nRF = 0.0000
# ✓ RF01590: median nRF = 0.0000
# ✓ RF01592: median nRF = 0.0000
# ✓ RF01595: median nRF = 0.0000
# ✓ RF01599: median nRF = 0.0000
# ✓ RF01600: median nRF = 1.0000
# ✓ RF01602: median nRF = 0.0000
# ✓ RF01607: median nRF = 0.0000
# ✓ RF01608: median nRF = 0.0000
# ✓ RF01609: median nRF = 0.0000
# ✓ RF01610: median nRF = 0.0000
# ✓ RF01620: median nRF = 0.0000
# ✓ RF01625: median nRF = 0.0000
# ✓ RF01626: median nRF = 0.0000
# ✓ RF01627: median nRF = 0.0000
# ✓ RF01629: median nRF = 0.0000
# ✓ RF01630: median nRF = 0.0000
# ✓ RF01633: median nRF = 0.0000
# ✓ RF01635: median nRF = 0.0000
# ✓ RF01637: median nRF = 0.0000
# ✓ RF01638: median nRF = 0.0000
# ✓ RF01643: median nRF = 0.0000
# ✓ RF01647: median nRF = 0.0000
# ✓ RF01651: median nRF = 0.0000
# ✓ RF01653: median nRF = 0.0000
# ✓ RF01654: median nRF = 0.0000
# ✓ RF01655: median nRF = 0.0000
# ✓ RF01656: median nRF = 0.1000
# ✓ RF01660: median nRF = 0.0000
# ✓ RF01661: median nRF = 0.0000
# ✓ RF01662: median nRF = 0.0000
# ✓ RF01663: median nRF = 0.0000
# ✓ RF01666: median nRF = 0.0000
# ✓ RF01668: median nRF = 0.0000
# ✓ RF01669: median nRF = 0.0000
# ✓ RF01671: median nRF = 0.0000
# ✓ RF01673: median nRF = 0.0000
# ✓ RF01674: median nRF = 0.0000
# ✓ RF01675: median nRF = 0.1250
# ✓ RF01676: median nRF = 0.0000
# ✓ RF01684: median nRF = 0.5417
# ✓ RF01685: median nRF = 0.0746
# ✓ RF01687: median nRF = 0.4776
# ✓ RF01688: median nRF = 0.2344
# ✓ RF01689: median nRF = 0.5766
# ✓ RF01690: median nRF = 0.3913
# ✓ RF01691: median nRF = 0.0476
# ✓ RF01692: median nRF = 0.2857
# ✓ RF01693: median nRF = 0.0000
# ✓ RF01694: median nRF = 0.1364
# ✓ RF01695: median nRF = 0.4557
# ✓ RF01696: median nRF = 0.4545
# ✓ RF01697: median nRF = 0.0667
# ✓ RF01699: median nRF = 0.4451
# ✓ RF01700: median nRF = 0.0000
# ✓ RF01701: median nRF = 0.5439
# ✓ RF01702: median nRF = 0.0189
# ✓ RF01703: median nRF = 0.0000
# ✓ RF01704: median nRF = 0.5770
# ✓ RF01705: median nRF = 0.6458
# ✓ RF01706: median nRF = 0.0667
# ✓ RF01707: median nRF = 0.2941
# ✓ RF01708: median nRF = 0.1667
# ✓ RF01709: median nRF = 0.0000
# ✓ RF01710: median nRF = 0.0000
# ✓ RF01711: median nRF = 0.2857
# ✓ RF01712: median nRF = 0.1935
# ✓ RF01713: median nRF = 0.5000
# ✓ RF01715: median nRF = 0.0000
# ✓ RF01716: median nRF = 0.4167
# ✓ RF01717: median nRF = 0.5433
# ✓ RF01718: median nRF = 0.2308
# ✓ RF01719: median nRF = 0.2222
# ✓ RF01720: median nRF = 0.0000
# ✓ RF01721: median nRF = 0.0909
# ✓ RF01722: median nRF = 0.0000
# ✓ RF01723: median nRF = 0.0000
# ✓ RF01724: median nRF = 0.1667
# ✓ RF01725: median nRF = 0.4696
# ✓ RF01726: median nRF = 0.5412
# ✓ RF01727: median nRF = 0.6136
# ✓ RF01728: median nRF = 0.1515
# ✓ RF01729: median nRF = 0.2000
# ✓ RF01730: median nRF = 0.2000
# ✓ RF01731: median nRF = 0.2640
# ✓ RF01732: median nRF = 0.1176
# ✓ RF01733: median nRF = 0.0000
# ✓ RF01734: median nRF = 0.6217
# ✓ RF01735: median nRF = 0.1481
# ✓ RF01736: median nRF = 0.0000
# ✓ RF01737: median nRF = 0.6000
# ✓ RF01738: median nRF = 0.1000
# ✓ RF01739: median nRF = 0.6667
# ✓ RF01740: median nRF = 0.0769
# ✓ RF01742: median nRF = 0.0000
# ✓ RF01743: median nRF = 0.0000
# ✓ RF01744: median nRF = 0.0000
# ✓ RF01745: median nRF = 0.3951
# ✓ RF01746: median nRF = 0.2424
# ✓ RF01747: median nRF = 0.4110
# ✓ RF01748: median nRF = 0.2941
# ✓ RF01749: median nRF = 0.4340
# ✓ RF01750: median nRF = 0.4828
# ✓ RF01751: median nRF = 0.5542
# ✓ RF01752: median nRF = 0.0357
# ✓ RF01753: median nRF = 0.2174
# ✓ RF01754: median nRF = 0.1756
# ✓ RF01755: median nRF = 0.0000
# ✓ RF01756: median nRF = 0.0000
# ✓ RF01757: median nRF = 0.0000
# ✓ RF01758: median nRF = 0.1111
# ✓ RF01759: median nRF = 0.0000
# ✓ RF01760: median nRF = 0.2439
# ✓ RF01761: median nRF = 0.4952
# ✓ RF01762: median nRF = 0.0909
# ✓ RF01763: median nRF = 0.2571
# ✓ RF01764: median nRF = 0.3556
# ✓ RF01766: median nRF = 0.0000
# ✓ RF01767: median nRF = 0.4091
# ✓ RF01768: median nRF = 0.0000
# ✓ RF01769: median nRF = 0.0000
# ✓ RF01770: median nRF = 0.3488
# ✓ RF01771: median nRF = 0.0000
# ✓ RF01772: median nRF = 0.0000
# ✓ RF01773: median nRF = 0.0000
# ✓ RF01774: median nRF = 0.0000
# ✓ RF01775: median nRF = 0.0000
# ✓ RF01776: median nRF = 0.0000
# ✓ RF01781: median nRF = 0.2174
# ✓ RF01782: median nRF = 0.7027
# ✓ RF01784: median nRF = 0.0000
# ✓ RF01786: median nRF = 0.4667
# ✓ RF01787: median nRF = 0.0000
# ✓ RF01788: median nRF = 0.0000
# ✓ RF01790: median nRF = 0.0000
# ✓ RF01791: median nRF = 0.0000
# ✓ RF01792: median nRF = 0.0000
# ✓ RF01793: median nRF = 0.4186
# ✓ RF01794: median nRF = 0.2159
# ✓ RF01796: median nRF = 0.0000
# ✓ RF01797: median nRF = 0.2632
# ✓ RF01802: median nRF = 0.0000
# ✓ RF01803: median nRF = 0.7347
# ✓ RF01804: median nRF = 0.5000
# ✓ RF01807: median nRF = 0.1000
# ✓ RF01808: median nRF = 0.0000
# ✓ RF01809: median nRF = 0.4706
# ✓ RF01810: median nRF = 0.4286
# ✓ RF01811: median nRF = 0.5000
# ✓ RF01813: median nRF = 0.2000
# ✓ RF01814: median nRF = 0.0000
# ✓ RF01815: median nRF = 0.0000
# ✓ RF01816: median nRF = 0.0000
# ✓ RF01819: median nRF = 0.0000
# ✓ RF01820: median nRF = 0.0833
# ✓ RF01821: median nRF = 0.0000
# ✓ RF01823: median nRF = 0.0000
# ✓ RF01824: median nRF = 0.0000
# ✓ RF01825: median nRF = 0.0000
# ✓ RF01826: median nRF = 0.0000
# ✓ RF01827: median nRF = 0.3000
# ✓ RF01830: median nRF = 0.5161
# ✓ RF01831: median nRF = 0.3402
# ✓ RF01832: median nRF = 0.0909
# ✓ RF01833: median nRF = 0.0000
# ✓ RF01834: median nRF = 0.5000
# ✓ RF01835: median nRF = 0.5000
# ✓ RF01836: median nRF = 0.0000
# ✓ RF01838: median nRF = 0.0000
# ✓ RF01839: median nRF = 0.5000
# ✓ RF01840: median nRF = 0.0909
# ✓ RF01841: median nRF = 0.8333
# ✓ RF01844: median nRF = 0.3448
# ✓ RF01845: median nRF = 0.0625
# ✓ RF01846: median nRF = 0.0159
# ✓ RF01847: median nRF = 0.0000
# ✓ RF01848: median nRF = 0.0800
# ✓ RF01849: median nRF = 0.1019
# ✓ RF01850: median nRF = 0.0000
# ✓ RF01851: median nRF = 0.4167
# ✓ RF01852: median nRF = 0.2857
# ✓ RF01853: median nRF = 0.2800
# ✓ RF01854: median nRF = 0.1481
# ✓ RF01855: median nRF = 0.1034
# ✓ RF01856: median nRF = 0.0000
# ✓ RF01857: median nRF = 0.0200
# ✓ RF01858: median nRF = 0.0000
# ✓ RF01859: median nRF = 0.0882
# ✓ RF01861: median nRF = 0.0000
# ✓ RF01862: median nRF = 0.0000
# ✓ RF01864: median nRF = 0.0000
# ✓ RF01865: median nRF = 0.0000
# ✓ RF01866: median nRF = 0.0000
# ✓ RF01867: median nRF = 0.0000
# ✓ RF01895: median nRF = 0.1795
# ✓ RF01896: median nRF = 0.1538
# ✓ RF01897: median nRF = 0.3750
# ✓ RF01898: median nRF = 0.1765
# ✓ RF01899: median nRF = 0.0000
# ✓ RF01900: median nRF = 0.2500
# ✓ RF01901: median nRF = 0.3333
# ✓ RF01902: median nRF = 0.5000
# ✓ RF01903: median nRF = 0.2333
# ✓ RF01911: median nRF = 0.0000
# ✓ RF01912: median nRF = 0.0000
# ✓ RF01913: median nRF = 0.5000
# ✓ RF01914: median nRF = 0.0000
# ✓ RF01915: median nRF = 0.1111
# ✓ RF01916: median nRF = 0.3333
# ✓ RF01917: median nRF = 0.0000
# ✓ RF01918: median nRF = 0.2500
# ✓ RF01919: median nRF = 0.1429
# ✓ RF01920: median nRF = 0.4000
# ✓ RF01921: median nRF = 0.5000
# ✓ RF01922: median nRF = 0.0000
# ✓ RF01923: median nRF = 0.0000
# ✓ RF01924: median nRF = 0.2500
# ✓ RF01925: median nRF = 0.2500
# ✓ RF01926: median nRF = 0.0769
# ✓ RF01927: median nRF = 0.0000
# ✓ RF01936: median nRF = 0.0000
# ✓ RF01937: median nRF = 0.0000
# ✓ RF01938: median nRF = 0.0000
# ✓ RF01939: median nRF = 0.6000
# ✓ RF01941: median nRF = 0.0000
# ✓ RF01943: median nRF = 0.0000
# ✓ RF01945: median nRF = 0.0000
# ✓ RF01959: median nRF = 0.1084
# ✓ RF01960: median nRF = 0.3678
# ✓ RF01982: median nRF = 0.0000
# ✓ RF01988: median nRF = 0.0000
# ✓ RF01989: median nRF = 0.0952
# ✓ RF01990: median nRF = 0.6667
# ✓ RF01996: median nRF = 0.0000
# ✓ RF01998: median nRF = 0.5328
# ✓ RF01999: median nRF = 0.4043
# ✓ RF02000: median nRF = 0.0000
# ✓ RF02001: median nRF = 0.3008
# ✓ RF02003: median nRF = 0.3333
# ✓ RF02004: median nRF = 0.2652
# ✓ RF02005: median nRF = 0.2440
# ✓ RF02009: median nRF = 0.0000
# ✓ RF02012: median nRF = 0.2795
# ✓ RF02017: median nRF = 0.0000
# ✓ RF02029: median nRF = 0.1875
# ✓ RF02030: median nRF = 0.0000
# ✓ RF02031: median nRF = 0.3333
# ✓ RF02032: median nRF = 0.0333
# ✓ RF02033: median nRF = 0.2059
# ✓ RF02034: median nRF = 0.2189
# ✓ RF02035: median nRF = 0.5426
# ✓ RF02036: median nRF = 0.0769
# ✓ RF02037: median nRF = 0.2500
# ✓ RF02051: median nRF = 0.1111
# ✓ RF02052: median nRF = 0.0000
# ✓ RF02053: median nRF = 0.0000
# ✓ RF02055: median nRF = 0.0000
# ✓ RF02057: median nRF = 0.5000
# ✓ RF02060: median nRF = 0.0909
# ✓ RF02061: median nRF = 0.1429
# ✓ RF02064: median nRF = 0.5714
# ✓ RF02065: median nRF = 0.0000
# ✓ RF02067: median nRF = 0.0000
# ✓ RF02068: median nRF = 0.0000
# ✓ RF02070: median nRF = 0.0000
# ✓ RF02074: median nRF = 0.3333
# ✓ RF02075: median nRF = 0.0000
# ✓ RF02076: median nRF = 0.0476
# ✓ RF02077: median nRF = 0.0000
# ✓ RF02079: median nRF = 0.0000
# ✓ RF02081: median nRF = 0.0000
# ✓ RF02083: median nRF = 0.0000
# ✓ RF02084: median nRF = 0.0000
# ✓ RF02088: median nRF = 0.0000
# ✓ RF02092: median nRF = 0.0000
# ✓ RF02093: median nRF = 0.1111
# ✓ RF02095: median nRF = 0.2000
# ✓ RF02100: median nRF = 0.1667
# ✓ RF02111: median nRF = 0.1250
# ✓ RF02144: median nRF = 0.0000
# ✓ RF02162: median nRF = 0.5510
# ✓ RF02194: median nRF = 0.0714
# ✓ RF02221: median nRF = 0.1618
# ✓ RF02222: median nRF = 0.0000
# ✓ RF02225: median nRF = 0.0000
# ✓ RF02226: median nRF = 1.0000
# ✓ RF02227: median nRF = 0.0000
# ✓ RF02228: median nRF = 0.5385
# ✓ RF02230: median nRF = 0.0000
# ✓ RF02231: median nRF = 1.0000
# ✓ RF02232: median nRF = 0.4000
# ✓ RF02233: median nRF = 0.0000
# ✓ RF02234: median nRF = 0.0000
# ✓ RF02235: median nRF = 0.0000
# ✓ RF02238: median nRF = 0.0000
# ✓ RF02240: median nRF = 0.0000
# ✓ RF02243: median nRF = 0.0000
# ✓ RF02253: median nRF = 0.5185
# ✓ RF02260: median nRF = 0.3636
# ✓ RF02261: median nRF = 0.2500
# ✓ RF02262: median nRF = 0.2222
# ✓ RF02263: median nRF = 0.2400
# ✓ RF02264: median nRF = 0.5556
# ✓ RF02265: median nRF = 0.2222
# ✓ RF02266: median nRF = 0.2000
# ✓ RF02268: median nRF = 0.0000
# ✓ RF02269: median nRF = 0.0000
# ✓ RF02270: median nRF = 0.5000
# ✓ RF02271: median nRF = 0.1290
# ✓ RF02273: median nRF = 0.0000
# ✓ RF02274: median nRF = 0.0000
# ✓ RF02275: median nRF = 0.5172
# ✓ RF02276: median nRF = 0.3500
# ✓ RF02277: median nRF = 0.1333
# ✓ RF02278: median nRF = 0.3542
# ✓ RF02339: median nRF = 0.0000
# ✓ RF02340: median nRF = 0.1250
# ✓ RF02341: median nRF = 0.0000
# ✓ RF02342: median nRF = 0.0556
# ✓ RF02343: median nRF = 0.0556
# ✓ RF02344: median nRF = 0.2079
# ✓ RF02345: median nRF = 0.2917
# ✓ RF02346: median nRF = 0.0000
# ✓ RF02347: median nRF = 0.0526
# ✓ RF02348: median nRF = 0.4062
# ✓ RF02349: median nRF = 0.0000
# ✓ RF02353: median nRF = 0.1429
# ✓ RF02354: median nRF = 0.0833
# ✓ RF02355: median nRF = 0.0000
# ✓ RF02356: median nRF = 0.0000
# ✓ RF02357: median nRF = 0.0000
# ✓ RF02359: median nRF = 0.5000
# ✓ RF02360: median nRF = 0.0000
# ✓ RF02362: median nRF = 0.0000
# ✓ RF02363: median nRF = 1.0000
# ✓ RF02364: median nRF = 0.0000
# ✓ RF02366: median nRF = 0.3333
# ✓ RF02367: median nRF = 0.0000
# ✓ RF02369: median nRF = 0.0000
# ✓ RF02370: median nRF = 0.0000
# ✓ RF02371: median nRF = 0.0000
# ✓ RF02372: median nRF = 0.5000
# ✓ RF02373: median nRF = 0.1250
# ✓ RF02374: median nRF = 0.0000
# ✓ RF02375: median nRF = 0.0000
# ✓ RF02376: median nRF = 0.0000
# ✓ RF02377: median nRF = 0.0000
# ✓ RF02378: median nRF = 0.0000
# ✓ RF02379: median nRF = 0.2667
# ✓ RF02384: median nRF = 0.0000
# ✓ RF02385: median nRF = 0.0000
# ✓ RF02386: median nRF = 0.0000
# ✓ RF02392: median nRF = 0.0000
# ✓ RF02396: median nRF = 0.0000
# ✓ RF02399: median nRF = 0.5714
# ✓ RF02400: median nRF = 0.0000
# ✓ RF02401: median nRF = 0.3429
# ✓ RF02402: median nRF = 0.2500
# ✓ RF02405: median nRF = 0.5000
# ✓ RF02408: median nRF = 0.0000
# ✓ RF02409: median nRF = 0.0000
# ✓ RF02410: median nRF = 0.6000
# ✓ RF02411: median nRF = 0.0000
# ✓ RF02412: median nRF = 0.0000
# ✓ RF02413: median nRF = 0.0000
# ✓ RF02414: median nRF = 0.0000
# ✓ RF02415: median nRF = 0.0000
# ✓ RF02419: median nRF = 0.4091
# ✓ RF02420: median nRF = 0.1250
# ✓ RF02421: median nRF = 0.0000
# ✓ RF02422: median nRF = 0.1111
# ✓ RF02423: median nRF = 0.0000
# ✓ RF02424: median nRF = 0.2727
# ✓ RF02425: median nRF = 0.0000
# ✓ RF02429: median nRF = 0.0000
# ✓ RF02431: median nRF = 0.3684
# ✓ RF02432: median nRF = 0.2941
# ✓ RF02433: median nRF = 1.0000
# ✓ RF02434: median nRF = 0.0000
# ✓ RF02435: median nRF = 0.0000
# ✓ RF02436: median nRF = 0.0000
# ✓ RF02437: median nRF = 0.1111
# ✓ RF02438: median nRF = 0.2000
# ✓ RF02440: median nRF = 0.6142
# ✓ RF02442: median nRF = 0.0000
# ✓ RF02444: median nRF = 0.0000
# ✓ RF02445: median nRF = 0.0000
# ✓ RF02446: median nRF = 0.4500
# ✓ RF02447: median nRF = 0.0500
# ✓ RF02448: median nRF = 0.2500
# ✓ RF02449: median nRF = 0.4615
# ✓ RF02450: median nRF = 0.0000
# ✓ RF02451: median nRF = 0.0000
# ✓ RF02452: median nRF = 0.0000
# ✓ RF02453: median nRF = 0.0000
# ✓ RF02454: median nRF = 0.0000
# ✓ RF02457: median nRF = 0.1667
# ✓ RF02459: median nRF = 0.0000
# ✓ RF02462: median nRF = 0.0000
# ✓ RF02463: median nRF = 0.0000
# ✓ RF02464: median nRF = 0.1667
# ✓ RF02465: median nRF = 0.1667
# ✓ RF02466: median nRF = 0.1429
# ✓ RF02469: median nRF = 0.8182
# ✓ RF02471: median nRF = 0.1667
# ✓ RF02495: median nRF = 0.4000
# ✓ RF02496: median nRF = 0.1667
# ...
# ✓ RF02957: median nRF = 0.2457
# ✓ RF02958: median nRF = 0.5290
# ✓ RF02959: median nRF = 0.3077
# ✓ RF02960: median nRF = 0.2123
# ✓ RF02961: median nRF = 0.2500
# ✓ RF02962: median nRF = 0.1731
# ✓ RF02963: median nRF = 0.1429
# ✓ RF02964: median nRF = 0.4342
# ✓ RF02965: median nRF = 0.3894
# ✓ RF02966: median nRF = 0.2600
# ✓ RF02967: median nRF = 0.2741
# ✓ RF02968: median nRF = 0.5000
# ✓ RF02969: median nRF = 0.3705
# ✓ RF02970: median nRF = 0.0000
# ✓ RF02971: median nRF = 0.1765
# ✓ RF02972: median nRF = 0.3361
# ✓ RF02973: median nRF = 0.1515
# ✓ RF02974: median nRF = 0.3750
# ✓ RF02975: median nRF = 0.4587
# ✓ RF02976: median nRF = 0.4320
# ✓ RF02977: median nRF = 0.5000
# ✓ RF02978: median nRF = 0.1500
# ✓ RF02979: median nRF = 0.2000
# ✓ RF02980: median nRF = 0.5939
# ✓ RF02981: median nRF = 0.2500
# ✓ RF02982: median nRF = 0.2308
# ✓ RF02983: median nRF = 0.0000
# ✓ RF02984: median nRF = 0.3647
# ✓ RF02985: median nRF = 0.2857
# ✓ RF02986: median nRF = 0.3614
# ✓ RF02987: median nRF = 0.4337
# ✓ RF02988: median nRF = 0.0000
# ✓ RF02989: median nRF = 0.0000
# ✓ RF02990: median nRF = 0.6000
# ✓ RF02991: median nRF = 0.3725
# ✓ RF02992: median nRF = 0.2632
# ✓ RF02993: median nRF = 0.0769
# ✓ RF02994: median nRF = 0.5000
# ✓ RF02995: median nRF = 0.3265
# ✓ RF02996: median nRF = 0.5099
# ✓ RF02997: median nRF = 0.0000
# ✓ RF02998: median nRF = 0.0377
# ✓ RF02999: median nRF = 0.4231
# ✓ RF03000: median nRF = 0.6016
# ✓ RF03001: median nRF = 0.5962
# ✓ RF03002: median nRF = 0.2500
# ✓ RF03003: median nRF = 0.5051
# ✓ RF03004: median nRF = 0.0000
# ✓ RF03005: median nRF = 0.3600
# ✓ RF03006: median nRF = 0.2000
# ✓ RF03007: median nRF = 0.2500
# ✓ RF03008: median nRF = 0.2609
# ✓ RF03009: median nRF = 0.1944
# ✓ RF03010: median nRF = 0.0000
# ✓ RF03011: median nRF = 0.0909
# ✓ RF03012: median nRF = 0.7061
# ✓ RF03013: median nRF = 0.6066
# ✓ RF03014: median nRF = 0.3419
# ✓ RF03015: median nRF = 0.6414
# ✓ RF03016: median nRF = 0.0909
# ✓ RF03017: median nRF = 0.0000
# ✓ RF03018: median nRF = 0.4262
# ✓ RF03019: median nRF = 0.3465
# ✓ RF03020: median nRF = 0.2963
# ✓ RF03021: median nRF = 0.3538
# ✓ RF03022: median nRF = 0.3182
# ✓ RF03023: median nRF = 0.0667
# ✓ RF03024: median nRF = 0.2222
# ✓ RF03025: median nRF = 0.2000
# ✓ RF03026: median nRF = 0.4412
# ✓ RF03027: median nRF = 0.2692
# ✓ RF03028: median nRF = 0.1277
# ✓ RF03029: median nRF = 0.0000
# ✓ RF03030: median nRF = 0.2727
# ✓ RF03031: median nRF = 0.5631
# ✓ RF03032: median nRF = 0.4954
# ✓ RF03033: median nRF = 0.0714
# ✓ RF03034: median nRF = 0.4000
# ✓ RF03035: median nRF = 0.0000
# ✓ RF03036: median nRF = 0.0435
# ✓ RF03037: median nRF = 0.2500
# ✓ RF03038: median nRF = 0.0833
# ✓ RF03039: median nRF = 0.1667
# ✓ RF03040: median nRF = 0.0667
# ✓ RF03041: median nRF = 0.1053
# ✓ RF03042: median nRF = 0.1071
# ✓ RF03043: median nRF = 0.0833
# ✓ RF03044: median nRF = 0.4286
# ✓ RF03045: median nRF = 0.1667
# ✓ RF03046: median nRF = 0.0638
# ✓ RF03047: median nRF = 0.0667
# ✓ RF03048: median nRF = 0.1667
# ✓ RF03049: median nRF = 0.0526
# ✓ RF03050: median nRF = 0.4000
# ✓ RF03051: median nRF = 0.0000
# ✓ RF03052: median nRF = 0.4051
# ✓ RF03053: median nRF = 0.3750
# ✓ RF03054: median nRF = 0.5992
# ✓ RF03055: median nRF = 0.2667
# ✓ RF03056: median nRF = 0.0000
# ✓ RF03057: median nRF = 0.7406
# ✓ RF03058: median nRF = 0.4286
# ✓ RF03059: median nRF = 0.4848
# ✓ RF03060: median nRF = 0.5333
# ✓ RF03061: median nRF = 0.1875
# ✓ RF03062: median nRF = 0.3478
# ✓ RF03063: median nRF = 0.1765
# ✓ RF03064: median nRF = 0.5435
# ✓ RF03065: median nRF = 0.3711
# ✓ RF03066: median nRF = 0.1111
# ✓ RF03067: median nRF = 0.6604
# ✓ RF03068: median nRF = 0.3284
# ✓ RF03069: median nRF = 0.3183
# ✓ RF03070: median nRF = 0.5938
# ✓ RF03071: median nRF = 0.3846
# ✓ RF03072: median nRF = 0.3177
# ✓ RF03073: median nRF = 0.1875
# ✓ RF03074: median nRF = 0.4057
# ✓ RF03075: median nRF = 0.5404
# ✓ RF03076: median nRF = 0.4211
# ✓ RF03077: median nRF = 0.2105
# ✓ RF03078: median nRF = 0.4286
# ✓ RF03079: median nRF = 0.0000
# ✓ RF03080: median nRF = 0.2381
# ✓ RF03081: median nRF = 0.6512
# ✓ RF03082: median nRF = 0.1923
# ✓ RF03083: median nRF = 0.0000
# ✓ RF03084: median nRF = 0.1579
# ✓ RF03085: median nRF = 0.4519
# ✓ RF03086: median nRF = 0.6601
# ✓ RF03087: median nRF = 0.2308
# ✓ RF03088: median nRF = 0.0000
# ✓ RF03089: median nRF = 0.0000
# ✓ RF03090: median nRF = 0.4400
# ✓ RF03091: median nRF = 0.0000
# ✓ RF03092: median nRF = 0.3077
# ✓ RF03093: median nRF = 0.0000
# ✓ RF03094: median nRF = 0.0000
# ✓ RF03095: median nRF = 0.0000
# ✓ RF03096: median nRF = 0.0000
# ✓ RF03097: median nRF = 0.1515
# ✓ RF03098: median nRF = 0.2000
# ✓ RF03099: median nRF = 0.0000
# ✓ RF03100: median nRF = 0.0833
# ✓ RF03101: median nRF = 0.2273
# ✓ RF03102: median nRF = 0.0000
# ✓ RF03103: median nRF = 0.2381
# ✓ RF03104: median nRF = 0.1818
# ✓ RF03105: median nRF = 0.0435
# ✓ RF03107: median nRF = 0.4286
# ✓ RF03108: median nRF = 0.0000
# ✓ RF03109: median nRF = 0.2222
# ✓ RF03110: median nRF = 0.0000
# ✓ RF03111: median nRF = 0.1250
# ✓ RF03112: median nRF = 0.3333
# ✓ RF03113: median nRF = 0.0000
# ✓ RF03114: median nRF = 0.0000
# ✓ RF03115: median nRF = 0.2414
# ✓ RF03116: median nRF = 0.0000
# ✓ RF03117: median nRF = 0.0714
# ✓ RF03119: median nRF = 0.0000
# ✓ RF03120: median nRF = 0.1250
# ✓ RF03121: median nRF = 0.0000
# ✓ RF03122: median nRF = 0.0000
# ✓ RF03124: median nRF = 0.0000
# ✓ RF03125: median nRF = 0.2500
# ✓ RF03126: median nRF = 0.3645
# ✓ RF03127: median nRF = 0.4923
# ✓ RF03128: median nRF = 0.3750
# ✓ RF03129: median nRF = 0.6100
# ✓ RF03130: median nRF = 0.8415
# ✓ RF03131: median nRF = 0.6111
# ✓ RF03132: median nRF = 0.6415
# ✓ RF03133: median nRF = 0.3016
# ✓ RF03134: median nRF = 0.2667
# ✓ RF03135: median nRF = 0.4840
# ✓ RF03136: median nRF = 0.5762
# ✓ RF03137: median nRF = 0.4787
# ✓ RF03138: median nRF = 0.6923
# ✓ RF03139: median nRF = 0.7128
# ✓ RF03140: median nRF = 0.6480
# ✓ RF03141: median nRF = 0.6705
# ✓ RF03142: median nRF = 0.5741
# ✓ RF03143: median nRF = 0.5096
# ✓ RF03144: median nRF = 0.5709
# ✓ RF03145: median nRF = 0.0000
# ✓ RF03146: median nRF = 0.1000
# ✓ RF03147: median nRF = 0.4795
# ✓ RF03148: median nRF = 0.1429
# ✓ RF03149: median nRF = 0.0952
# ✓ RF03150: median nRF = 0.0000
# ✓ RF03151: median nRF = 0.2609
# ✓ RF03152: median nRF = 0.1538
# ✓ RF03153: median nRF = 0.0833
# ✓ RF03154: median nRF = 0.1667
# ✓ RF03155: median nRF = 0.3200
# ✓ RF03156: median nRF = 0.8236
# ✓ RF03157: median nRF = 0.5528
# ✓ RF03158: median nRF = 0.8165
# ✓ RF03159: median nRF = 0.2195
# ✓ RF03160: median nRF = 0.7616
# ✓ RF03161: median nRF = 0.6756
# ✓ RF03162: median nRF = 0.5152
# ✓ RF03163: median nRF = 0.2500
# ✓ RF03164: median nRF = 0.0000
# ✓ RF03165: median nRF = 0.0741
# ✓ RF03166: median nRF = 0.1429
# ✓ RF03167: median nRF = 0.4865
# ✓ RF03168: median nRF = 1.0000
# ✓ RF03169: median nRF = 0.6226
# ✓ RF03170: median nRF = 0.2667
# ✓ RF03175: median nRF = 0.0000
# ✓ RF03184: median nRF = 0.0000
# ✓ RF03186: median nRF = 0.0000
# ✓ RF03189: median nRF = 0.0000
# ✓ RF03193: median nRF = 0.0000
# ✓ RF03198: median nRF = 0.0000
# ✓ RF03199: median nRF = 1.0000
# ✓ RF03212: median nRF = 0.0000
# ✓ RF03214: median nRF = 0.2500
# ✓ RF03218: median nRF = 0.0000
# ✓ RF03229: median nRF = 0.0000
# ✓ RF03242: median nRF = 0.0000
# ✓ RF03249: median nRF = 0.0000
# ✓ RF03251: median nRF = 0.0000
# ✓ RF03254: median nRF = 1.0000
# ✓ RF03255: median nRF = 0.0000
# ✓ RF03258: median nRF = 0.0000
# ✓ RF03271: median nRF = 0.0000
# ✓ RF03278: median nRF = 0.0000
# ✓ RF03279: median nRF = 0.2000
# ✓ RF03280: median nRF = 1.0000
# ✓ RF03283: median nRF = 0.0000
# ✓ RF03292: median nRF = 0.0000
# ✓ RF03296: median nRF = 0.0000
# ✓ RF03297: median nRF = 0.0000
# ✓ RF03299: median nRF = 0.0000
# ✓ RF03301: median nRF = 0.0000
# ✓ RF03310: median nRF = 0.0000
# ✓ RF03311: median nRF = 0.0000
# ✓ RF03313: median nRF = 0.3333
# ✓ RF03319: median nRF = 0.1667
# ✓ RF03321: median nRF = 0.0000
# ✓ RF03325: median nRF = 0.0000
# ✓ RF03326: median nRF = 0.3333
# ✓ RF03329: median nRF = 1.0000
# ✓ RF03330: median nRF = 0.0000
# ✓ RF03349: median nRF = 0.0000
# ✓ RF03350: median nRF = 0.0000
# ✓ RF03354: median nRF = 0.0000
# ✓ RF03355: median nRF = 0.0000
# ✓ RF03357: median nRF = 0.0000
# ✓ RF03368: median nRF = 0.0000
# ✓ RF03369: median nRF = 0.0000
# ✓ RF03372: median nRF = 0.0000
# ✓ RF03374: median nRF = 0.0000
# ✓ RF03378: median nRF = 0.0000
# ✓ RF03379: median nRF = 1.0000
# ✓ RF03381: median nRF = 0.0000
# ✓ RF03386: median nRF = 0.0000
# ✓ RF03390: median nRF = 0.0000
# ✓ RF03395: median nRF = 0.0000
# ✓ RF03402: median nRF = 0.0000
# ✓ RF03404: median nRF = 0.2500
# ✓ RF03408: median nRF = 0.0000
# ✓ RF03414: median nRF = 0.0000
# ✓ RF03419: median nRF = 0.0000
# ✓ RF03436: median nRF = 0.0000
# ✓ RF03442: median nRF = 0.0000
# ✓ RF03444: median nRF = 0.0000
# ✓ RF03445: median nRF = 0.0000
# ✓ RF03456: median nRF = 0.2500
# ✓ RF03464: median nRF = 0.0000
# ✓ RF03469: median nRF = 0.0000
# ✓ RF03470: median nRF = 0.0000
# ✓ RF03471: median nRF = 0.0000
# ✓ RF03479: median nRF = 0.3333
# ✓ RF03480: median nRF = 0.0000
# ✓ RF03483: median nRF = 0.0000
# ✓ RF03485: median nRF = 0.0000
# ✓ RF03495: median nRF = 0.0000
# ✓ RF03508: median nRF = 0.0000
# ✓ RF03517: median nRF = 0.0000
# ✓ RF03525: median nRF = 0.0000
# ✓ RF03528: median nRF = 0.0000
# ✓ RF03530: median nRF = 0.0000
# ✓ RF03531: median nRF = 0.0526
# ✓ RF03532: median nRF = 0.0000
# ✓ RF03533: median nRF = 0.0000
# ✓ RF03534: median nRF = 0.0000
# ✓ RF03536: median nRF = 0.1333
# ✓ RF03537: median nRF = 0.1429
# ✓ RF03538: median nRF = 0.0000
# ✓ RF03541: median nRF = 0.2000
# ✓ RF03542: median nRF = 0.0000
# ✓ RF03543: median nRF = 0.3750
# ✓ RF03544: median nRF = 0.0370
# ✓ RF03545: median nRF = 0.0000
# ✓ RF03546: median nRF = 0.0000
# ✓ RF03547: median nRF = 0.4444
# ✓ RF03552: median nRF = 0.0000
# ✓ RF03565: median nRF = 0.0000
# ✓ RF03600: median nRF = 0.0000
# ✓ RF03601: median nRF = 0.0000
# ✓ RF03602: median nRF = 0.0000
# ✓ RF03608: median nRF = 1.0000
# ✓ RF03620: median nRF = 0.0000
# ✓ RF03623: median nRF = 1.0000
# ✓ RF03632: median nRF = 0.4000
# ✓ RF03639: median nRF = 0.0000
# ✓ RF03653: median nRF = 0.0000
# ✓ RF03661: median nRF = 0.0000
# ✓ RF03662: median nRF = 0.2500
# ✓ RF03668: median nRF = 0.0000
# ✓ RF03669: median nRF = 0.0000
# ✓ RF03684: median nRF = 0.0000
# ✓ RF03687: median nRF = 0.0000
# ✓ RF03691: median nRF = 0.0000
# ✓ RF03692: median nRF = 0.0000
# ✓ RF03693: median nRF = 0.0000
# ✓ RF03695: median nRF = 0.1667
# ✓ RF03706: median nRF = 0.0000
# ✓ RF03714: median nRF = 0.0000
# ✓ RF03718: median nRF = 0.0000
# ✓ RF03731: median nRF = 0.0000
# ✓ RF03741: median nRF = 0.0000
# ✓ RF03760: median nRF = 1.0000
# ✓ RF03767: median nRF = 0.0000
# ✓ RF03768: median nRF = 0.0000
# ✓ RF03777: median nRF = 0.0000
# ✓ RF03778: median nRF = 0.0000
# ✓ RF03779: median nRF = 0.0000
# ✓ RF03784: median nRF = 0.0000
# ✓ RF03792: median nRF = 0.0000
# ✓ RF03794: median nRF = 0.0000
# ✓ RF03803: median nRF = 0.0000
# ✓ RF03814: median nRF = 0.0000
# ✓ RF03833: median nRF = 0.0000
# ✓ RF03834: median nRF = 0.5000
# ✓ RF03838: median nRF = 1.0000
# ✓ RF03840: median nRF = 0.0000
# ✓ RF03842: median nRF = 0.0000
# ✓ RF03843: median nRF = 0.5000
# ✓ RF03849: median nRF = 0.0000
# ✓ RF03851: median nRF = 0.0000
# ✓ RF03860: median nRF = 0.4667
# ✓ RF03875: median nRF = 0.0000
# ✓ RF03881: median nRF = 0.0000
# ✓ RF03883: median nRF = 0.0000
# ✓ RF03896: median nRF = 0.0000
# ✓ RF03939: median nRF = 0.0000
# ✓ RF03944: median nRF = 0.0000
# ✓ RF03947: median nRF = 0.0000
# ✓ RF03956: median nRF = 0.5000
# ✓ RF03962: median nRF = 0.0000
# ✓ RF03969: median nRF = 0.0000
# ✓ RF03981: median nRF = 0.5000
# ✓ RF03983: median nRF = 0.2000
# ✓ RF03995: median nRF = 0.0000
# ✓ RF03997: median nRF = 0.3333
# ✓ RF04000: median nRF = 1.0000
# ✓ RF04001: median nRF = 0.0000
# ✓ RF04009: median nRF = 0.3333
# ✓ RF04027: median nRF = 0.1333
# ✓ RF04029: median nRF = 0.3750
# ✓ RF04044: median nRF = 0.1429
# ✓ RF04045: median nRF = 0.0000
# ✓ RF04048: median nRF = 1.0000
# ✓ RF04052: median nRF = 0.5000
# ✓ RF04053: median nRF = 0.1111
# ✓ RF04054: median nRF = 0.0000
# ✓ RF04056: median nRF = 0.0000
# ✓ RF04057: median nRF = 0.0000
# ✓ RF04061: median nRF = 0.0000
# ✓ RF04063: median nRF = 0.0000
# ✓ RF04064: median nRF = 0.4286
# ✓ RF04066: median nRF = 0.0000
# ✓ RF04067: median nRF = 0.0000
# ✓ RF04069: median nRF = 0.5000
# ✓ RF04072: median nRF = 0.0000
# ✓ RF04073: median nRF = 0.0000
# ✓ RF04074: median nRF = 0.0000
# ✓ RF04075: median nRF = 0.0000
# ✓ RF04076: median nRF = 0.0000
# ✓ RF04077: median nRF = 0.0000
# ✓ RF04078: median nRF = 0.0000
# ✓ RF04079: median nRF = 0.0000
# ✓ RF04080: median nRF = 0.0000
# ✓ RF04082: median nRF = 0.0000
# ✓ RF04083: median nRF = 0.2500
# ✓ RF04084: median nRF = 0.0000
# ✓ RF04085: median nRF = 0.2857
# ✓ RF04087: median nRF = 0.0000
# ✓ RF04088: median nRF = 0.3684
# ✓ RF04089: median nRF = 0.0000
# ✓ RF04090: median nRF = 0.0000
# ✓ RF04091: median nRF = 0.0000
# ✓ RF04095: median nRF = 1.0000
# ✓ RF04097: median nRF = 0.1500
# ✓ RF04100: median nRF = 0.4000
# ✓ RF04117: median nRF = 0.0000
# ✓ RF04121: median nRF = 0.0000
# ✓ RF04122: median nRF = 0.0000
# ✓ RF04124: median nRF = 0.0000
# ✓ RF04126: median nRF = 0.0000
# ✓ RF04134: median nRF = 0.0000
# ✓ RF04136: median nRF = 0.0000
# ✓ RF04150: median nRF = 0.2727
# ✓ RF04151: median nRF = 0.0000
# ✓ RF04154: median nRF = 0.0000
# ✓ RF04156: median nRF = 0.0000
# ✓ RF04158: median nRF = 0.0000
# ✓ RF04163: median nRF = 0.2000
# ✓ RF04164: median nRF = 0.0000
# ✓ RF04165: median nRF = 0.0000
# ✓ RF04169: median nRF = 0.7500
# ✓ RF04171: median nRF = 0.0000
# ✓ RF04175: median nRF = 0.0000
# ✓ RF04179: median nRF = 0.0000
# ✓ RF04180: median nRF = 0.0000
# ✓ RF04181: median nRF = 0.0000
# ✓ RF04182: median nRF = 0.0000
# ✓ RF04183: median nRF = 0.0500
# ✓ RF04188: median nRF = 0.0769
# ✓ RF04189: median nRF = 0.0000
# ✓ RF04190: median nRF = 0.6543
# ✓ RF04191: median nRF = 0.1556
# ✓ RF04192: median nRF = 0.0345
# ✓ RF04193: median nRF = 0.0000
# ✓ RF04194: median nRF = 0.0000
# ✓ RF04204: median nRF = 0.0000
# ✓ RF04205: median nRF = 0.0000
# ✓ RF04211: median nRF = 0.2000
# ✓ RF04214: median nRF = 0.0000
# ✓ RF04216: median nRF = 0.2188
# ✓ RF04217: median nRF = 0.1250
# ✓ RF04218: median nRF = 0.3778
# ✓ RF04219: median nRF = 0.4902
# ✓ RF04220: median nRF = 0.3922
# ✓ RF04221: median nRF = 0.6042
# ✓ RF04222: median nRF = 0.6000
# ✓ RF04224: median nRF = 0.2500
# ✓ RF04225: median nRF = 0.0000
# ✓ RF04226: median nRF = 0.1786
# ✓ RF04227: median nRF = 0.0000
# ✓ RF04228: median nRF = 0.0000
# ✓ RF04229: median nRF = 0.0000
# ✓ RF04234: median nRF = 0.1200
# ✓ RF04235: median nRF = 0.0000
# ✓ RF04236: median nRF = 0.0000
# ✓ RF04244: median nRF = 0.0000
# ✓ RF04247: median nRF = 0.2597
# ✓ RF04248: median nRF = 0.0000
# ✓ RF04249: median nRF = 0.0000
# ✓ RF04250: median nRF = 0.0000
# ✓ RF04254: median nRF = 0.0000
# ✓ RF04261: median nRF = 0.1000
# ✓ RF04263: median nRF = 0.0000
# ✓ RF04266: median nRF = 0.2500
# ✓ RF04267: median nRF = 0.3333
# ✓ RF04268: median nRF = 0.5000
# ✓ RF04269: median nRF = 0.0000
# ✓ RF04270: median nRF = 0.0000
# ✓ RF04271: median nRF = 0.6667
# ✓ RF04272: median nRF = 0.0645
# ✓ RF04274: median nRF = 0.3333
# ✓ RF04275: median nRF = 0.0000
# ✓ RF04276: median nRF = 0.0000
# ✓ RF04280: median nRF = 0.0769
# ✓ RF04282: median nRF = 0.0556
# ✓ RF04284: median nRF = 0.0000
# ✓ RF04285: median nRF = 0.0000
# ✓ RF04286: median nRF = 0.1290
# ✓ RF04288: median nRF = 0.3333
# ✓ RF04290: median nRF = 0.0000
# ✓ RF04291: median nRF = 0.2000
# ✓ RF04292: median nRF = 0.0345
# ✓ RF04293: median nRF = 0.0000
# ✓ RF04294: median nRF = 0.0000
# ✓ RF04295: median nRF = 0.1333
# ✓ RF04296: median nRF = 0.0000
# ✓ RF04297: median nRF = 0.1667
# ✓ RF04300: median nRF = 0.0000
# ✓ RF04302: median nRF = 0.0000
# ✓ RF04303: median nRF = 0.0000
# ✓ RF04305: median nRF = 0.3077
# ✓ RF04306: median nRF = 0.5577
# ✓ RF04307: median nRF = 0.3208
# ✓ RF04308: median nRF = 0.5849
# ✓ RF04309: median nRF = 0.0943
# ✓ RF04310: median nRF = 0.0000
#
# ✓ Processed 2260 RNA families from DNA_extra
#
# ✓ Appended DNA_extra to seed_medians (duplicate rows removed)
#   New total rows: 27292
#   DNA_extra rows: 2260
#
# ======================================================================
# Creating CSV with median normalised RF distances
# ======================================================================
# ✓ Saved to: /Users/u7875558/RNAPhylo/seedAlignment_AllModels/outputs/SEED_Median_nRF_with_DNA_extra.csv
#   Total rows: 27292
#
# First 5 rows:
#        RNA  Comparison  Median nRF
# 0  RF00011  DNA vs S16    0.297297
# 1  RF00014  DNA vs S16    0.000000
# 2  RF00016  DNA vs S16    0.266667
# 3  RF00018  DNA vs S16    0.257143
# 4  RF00019  DNA vs S16    0.626374
#
# ======================================================================

# %%
#!/usr/bin/env python3
"""
Focused violin plot: DNA vs DNA_extra
Shows variability in median RF distances between DNA and DNA_extra datasets
(representing DNA trees inferred with different random seeds)
"""

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# ─── 1) EXTRACT DNA_EXTRA DATA ──────────────────────────────────────────────────
df_dna_extra = seed_medians[
    (seed_medians['Model'] == 'DNA_extra') & 
    (seed_medians['Category'] == 'DNA vs extra DNA')
].copy()

if len(df_dna_extra) == 0:
    print("✗ ERROR: No DNA_extra data found. Check seed_medians dataframe.")
else:
    # ─── 2) PREPARE DATA FOR VIOLIN PLOT ────────────────────────────────────────
    df_dna_extra['Group'] = 'DNA vs DNA_extra'
    
    nrna = len(df_dna_extra)
    n_mean = df_dna_extra['Median nRF'].mean()
    n_median = df_dna_extra['Median nRF'].median()
    n_std = df_dna_extra['Median nRF'].std()
    
    # ─── 3) PLOT: VIOLIN + STRIP ───────────────────────────────────────────────
    plt.figure(figsize=(8, 6))
    
    sns.violinplot(
        data=df_dna_extra,
        x='Group',
        y='Median nRF',
        palette={'DNA vs DNA_extra': '#606060'},  # dark gray
        cut=0,
        inner='quartile',  # show median & IQR
        linewidth=1.2
    )
    
    # Overlay individual RNA points
    sns.stripplot(
        data=df_dna_extra,
        x='Group',
        y='Median nRF',
        color='black',
        alpha=0.3,
        size=4,
        jitter=True
    )
    
    # ─── 4) LABELS & FORMATTING ────────────────────────────────────────────────
    ymax = df_dna_extra['Median nRF'].max()
    plt.ylim(0, ymax * 1.2)
    
    plt.ylabel('Median Normalised RF Distance', fontsize=11, fontweight='bold')
    plt.xlabel('')
    plt.title('DNA vs DNA_extra Comparison\n(Variability in RF distances between DNA random seeds)', 
              fontsize=12, fontweight='bold', pad=15)
    plt.grid(axis='y', alpha=0.3, linestyle='--')
    plt.tight_layout()
    plt.show()
    
    # ─── 5) SUMMARY STATISTICS ────────────────────────────────────────────────
    print("\n" + "="*70)
    print("SUMMARY: DNA vs DNA_extra (RF Distance Variability)")
    print("="*70)
    print(f"N RNA families:        {nrna}")
    print(f"Mean nRF:              {n_mean:.4f}")
    print(f"Median nRF:            {n_median:.4f}")
    print(f"Std Dev:               {n_std:.4f}")
    print(f"Min:                   {df_dna_extra['Median nRF'].min():.4f}")
    print(f"Max:                   {df_dna_extra['Median nRF'].max():.4f}")
    print("="*70)
    print("\nInterpretation:")
    print("- This shows how much tree topologies vary between random seeds")
    print("- High median nRF → significant seed-induced variation in DNA trees")
    print("- Low median nRF → DNA trees robust across different random seeds")
# Out:
# /var/folders/7l/28yzqfm93j105y85x5rns4bryc93vy/T/ipykernel_7361/4266625711.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# ======================================================================
# SUMMARY: DNA vs DNA_extra (RF Distance Variability)
# ======================================================================
# N RNA families:        2260
# Mean nRF:              0.1653
# Median nRF:            0.0465
# Std Dev:               0.2203
# Min:                   0.0000
# Max:                   1.0000
# ======================================================================
#
# Interpretation:
# - This shows how much tree topologies vary between random seeds
# - High median nRF → significant seed-induced variation in DNA trees
# - Low median nRF → DNA trees robust across different random seeds

# %%
#!/usr/bin/env python3
"""
Violin plot: DNA_extra, S16, S7A, S6A with connecting lines
Shows median nRF differences across representative models
Lines visible only when difference >= 25% between adjacent groups
"""

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# ─── 1) FILTER DATA FOR SELECTED COMPARISONS ───────────────────────────────────
comparisons_to_show = ['DNA vs DNA_extra', 'DNA vs S16', 'DNA vs S7A', 'DNA vs S6A']
groups_order = comparisons_to_show

# Extract data for selected comparisons
df_filtered = seed_medians[seed_medians['Comparison'].isin(comparisons_to_show)].copy()

if len(df_filtered) == 0:
    print("✗ ERROR: No data found for selected comparisons")
else:
    # ─── 2) PIVOT TO WIDE FORMAT FOR CONNECTING LINES ──────────────────────────
    df_wide = df_filtered.pivot(index='RNA', columns='Comparison', values='Median nRF')
    df_wide = df_wide.reindex(columns=groups_order)
    df_wide_complete = df_wide.dropna(how='any')  # keep only RNAs with all 4 groups
    
    # ─── 3) COLOR PALETTE ────────────────────────────────────────────────────────
    palette = {
        'DNA vs DNA_extra': '#606060',  # dark gray
        'DNA vs S16': '#FF9500',        # orange
        'DNA vs S7A': '#1F77B4',        # blue
        'DNA vs S6A': '#2CA02C'         # green
    }
    
    # ─── 4) PLOT: VIOLIN + CONNECTING LINES ──────────────────────────────────────
    plt.figure(figsize=(10, 6))
    
    # Violin plot
    sns.violinplot(
        data=df_filtered,
        x='Comparison',
        y='Median nRF',
        order=groups_order,
        palette=palette,
        cut=0,
        inner='box',  # show median & quartiles
        linewidth=1.0
    )
    
    # Add connecting lines for RNAs with ≥25% difference
    xpos = np.arange(len(groups_order))
    threshold = 0.25  # 25% relative difference threshold
    
    for rna, row in df_wide_complete.iterrows():
        vals = row.values.astype(float)
        
        # Draw lines between adjacent groups
        for i in range(len(vals) - 1):
            v1, v2 = vals[i], vals[i+1]
            
            # Skip if both are NaN
            if np.isnan(v1) or np.isnan(v2):
                continue
            
            # Calculate relative difference
            if v1 == 0 and v2 == 0:
                rel_diff = 0
            elif v1 == 0 or v2 == 0:
                rel_diff = max(abs(v1), abs(v2))  # use absolute value if one is zero
            else:
                rel_diff = abs(v2 - v1) / min(abs(v1), abs(v2))
            
            # Draw line only if difference >= 25%
            if rel_diff >= threshold:
                plt.plot([xpos[i], xpos[i+1]], [v1, v2],
                        color='black', alpha=0.10, linewidth=0.8, zorder=1)
    
    # ─── 5) LABELS & FORMATTING ─────────────────────────────────────────────────
    ymax = df_filtered['Median nRF'].max()
    plt.ylim(0, ymax * 1.15)
    
    plt.xlabel('Comparison Group', fontsize=11, fontweight='bold')
    plt.ylabel('Median Normalised RF Distance', fontsize=11, fontweight='bold')
    plt.title(f'Median Normalised RF: DNA_extra vs S16, S7A, S6A\n(Lines shown for ≥{threshold*100}% difference)', 
              fontsize=12, fontweight='bold', pad=15)
    plt.xticks(rotation=15, ha='right')
    plt.grid(axis='y', alpha=0.3, linestyle='--')
    plt.tight_layout()
    plt.show()
    
    # ─── 6) SUMMARY STATISTICS ──────────────────────────────────────────────────
    print("\n" + "="*70)
    print("SUMMARY: Median Normalised RF Distances (Selected Models)")
    print("="*70)
    print(f"RNAs with complete data across all 4 groups: {len(df_wide_complete)}")
    print("\nMedian nRF per Comparison Group:")
    print("-"*70)
    
    for comp in groups_order:
        data = df_filtered[df_filtered['Comparison'] == comp]['Median nRF']
        print(f"{comp:25} | N={len(data):3} | Median={data.median():.4f} | Mean={data.mean():.4f} | Std={data.std():.4f}")
    
    print("="*70)
# Out:
# /var/folders/7l/28yzqfm93j105y85x5rns4bryc93vy/T/ipykernel_7361/2858893298.py:40: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# ======================================================================
# SUMMARY: Median Normalised RF Distances (Selected Models)
# ======================================================================
# RNAs with complete data across all 4 groups: 1788
#
# Median nRF per Comparison Group:
# ----------------------------------------------------------------------
# DNA vs DNA_extra          | N=2260 | Median=0.0465 | Mean=0.1653 | Std=0.2203
# DNA vs S16                | N=1788 | Median=0.2667 | Mean=0.2975 | Std=0.2889
# DNA vs S7A                | N=1788 | Median=0.2500 | Mean=0.2847 | Std=0.2876
# DNA vs S6A                | N=1788 | Median=0.2727 | Mean=0.3078 | Std=0.3011
# ======================================================================

# %%
import re
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# --- 1) Build plotting frame without touching df_medians -----------------------
# Baseline: only from DNA_extra, rename to "DNA vs DNA"
base_mask = (seed_medians['Model'] == 'DNA_extra') & (seed_medians['Category'] == 'DNA vs extra DNA')
df_base = (
    seed_medians.loc[base_mask, ['RNA', 'Median nRF']].copy()
               .assign(Group='DNA vs DNA')
)

# S-models: keep DNA vs RNA rows from all non-DNA_extra models
df_models = seed_medians[
    (seed_medians['Model'] != 'DNA_extra')
    & (seed_medians['Category'].str.startswith('DNA vs RNA'))
].copy()

# Ensure the group label is "DNA vs RNA (MODEL)" (if not already)
def ensure_group(row):
    cat = str(row['Category'])
    if '(' in cat and ')' in cat:
        return cat
    return f"DNA vs RNA ({row['Model']})"

df_models['Group'] = df_models.apply(ensure_group, axis=1)

# Combine for plotting
df_plot = pd.concat(
    [df_base[['RNA','Group','Median nRF']], df_models[['RNA','Group','Median nRF']]],
    ignore_index=True
).dropna(subset=['Median nRF'])

# --- 2) Order groups: baseline → S16* → S7* → S6* ------------------------------
all_groups = sorted(df_plot['Group'].unique())

def pick(prefix):
    return sorted([g for g in all_groups if re.search(rf'\({prefix}', g)],
                  key=lambda g: re.search(r'\(([^)]+)\)', g).group(1))

order = ['DNA vs DNA']
order += pick('S16') + pick('S7') + pick('S6')

# --- 3) Colors -----------------------------------------------------------------
palette = {'DNA vs DNA': '#d3d3d3'}  # light gray baseline

def shade(groups, cmap):
    if not groups: return {}
    cols = sns.color_palette(cmap, len(groups))
    return {g: cols[i] for i, g in enumerate(groups)}

palette |= shade([g for g in order if '(S16' in g], 'Oranges')
palette |= shade([g for g in order if '(S7'  in g], 'Blues')
palette |= shade([g for g in order if '(S6'  in g], 'Greens')

# --- 4) Plot -------------------------------------------------------------------
plt.figure(figsize=(max(10, 0.6*len(order)), 5))
sns.violinplot(
    data=df_plot[df_plot['Group'].isin(order)],
    x='Group', y='Median nRF',
    order=order, palette=palette,
    cut=0,           # cut only at the bottom (no extension below 0)
    inner=None
)

#ymax = df_plot['Median nRF'].max()
#plt.ylim(0, ymax * 1.15 if np.isfinite(ymax) else None)
plt.xticks(rotation=30, ha='right')
plt.ylabel('Median Normalised RF')
plt.xlabel('')
plt.title('Median Normalised Robinson-Foulds Distance -- All Models for seed-alignment dataset')
plt.tight_layout()
plt.show()

# --- 5) Quick summaries (optional) ---------------------------------------------
print('Group medians:')
print(df_plot.groupby('Group')['Median nRF'].median().reindex(order).round(4))
print('\nGroup means:')
print(df_plot.groupby('Group')['Median nRF'].mean().reindex(order).round(4))
# Out:
# /var/folders/7l/28yzqfm93j105y85x5rns4bryc93vy/T/ipykernel_7361/901520769.py:60: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# Group medians:
# Group
# DNA vs DNA           0.0465
# DNA vs RNA (S16)     0.2667
# DNA vs RNA (S16A)    0.2222
# DNA vs RNA (S16B)    0.2727
# DNA vs RNA (S7A)     0.2500
# DNA vs RNA (S7B)     0.2500
# DNA vs RNA (S7C)     0.2353
# DNA vs RNA (S7D)     0.2222
# DNA vs RNA (S7E)     0.2240
# DNA vs RNA (S7F)     0.2143
# DNA vs RNA (S6A)     0.2727
# DNA vs RNA (S6B)     0.2500
# DNA vs RNA (S6C)     0.2500
# DNA vs RNA (S6D)     0.2500
# DNA vs RNA (S6E)     0.2500
# Name: Median nRF, dtype: float64
#
# Group means:
# Group
# DNA vs DNA           0.1653
# DNA vs RNA (S16)     0.2975
# DNA vs RNA (S16A)    0.2681
# DNA vs RNA (S16B)    0.3018
# DNA vs RNA (S7A)     0.2847
# DNA vs RNA (S7B)     0.2792
# DNA vs RNA (S7C)     0.2788
# DNA vs RNA (S7D)     0.2716
# DNA vs RNA (S7E)     0.2740
# DNA vs RNA (S7F)     0.2689
# DNA vs RNA (S6A)     0.3078
# DNA vs RNA (S6B)     0.3006
# DNA vs RNA (S6C)     0.2991
# DNA vs RNA (S6D)     0.2994
# DNA vs RNA (S6E)     0.3016
# Name: Median nRF, dtype: float64

# %%
import re
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# ---------- 1) Build the plotting frame (drop DNA vs DNA, keep extra→rename) ----------
base_mask = (seed_medians['Model'] == 'DNA_extra') & (seed_medians['Category'] == 'DNA vs extra DNA')
df_base = (
    seed_medians.loc[base_mask, ['RNA','Median nRF']].copy()
               .assign(Group='DNA vs DNA')              # rename for plotting
)

# keep all S-model DNA vs RNA rows
df_models = seed_medians[
    (seed_medians['Model'] != 'DNA_extra')
    & (seed_medians['Category'].str.startswith('DNA vs RNA'))
].copy()

def ensure_group(row):
    cat = str(row['Category'])
    if '(' in cat and ')' in cat:
        return cat
    return f"DNA vs RNA ({row['Model']})"

df_models['Group'] = df_models.apply(ensure_group, axis=1)

df_plot = pd.concat(
    [df_base[['RNA','Group','Median nRF']], df_models[['RNA','Group','Median nRF']]],
    ignore_index=True
).dropna(subset=['Median nRF'])

# ---------- 2) Order groups: DNA baseline → S16* → S7* → S6* ----------
all_groups = sorted(df_plot['Group'].unique())

def pick(prefix):
    return sorted([g for g in all_groups if re.search(rf'\({prefix}', g)],
                  key=lambda g: re.search(r'\(([^)]+)\)', g).group(1))

order = ['DNA vs DNA'] + pick('S16') + pick('S7') + pick('S6')

# ---------- 3) Palette ----------
palette = {'DNA vs DNA': '#d3d3d3'}  # light gray
def shade(groups, cmap):
    if not groups: return {}
    cols = sns.color_palette(cmap, len(groups))
    return {g: cols[i] for i, g in enumerate(groups)}
palette |= shade([g for g in order if '(S16' in g], 'Oranges')
palette |= shade([g for g in order if '(S7'  in g], 'Blues')
palette |= shade([g for g in order if '(S6'  in g], 'Greens')

# ---------- 4) Boundary-corrected KDE copy just for the violin ----------
eps = 1e-4
rng = np.random.default_rng(0)

df_kde = df_plot.copy()
y = df_kde['Median nRF'].to_numpy().astype(float)

# jitter exact 0 and exact 1 slightly inward (for KDE only)
zeros = (y == 0.0)
ones  = (y == 1.0)
y[zeros] += rng.uniform(eps, 5*eps, zeros.sum())
y[ones]  -= rng.uniform(eps, 5*eps, ones.sum())
# clip to (eps, 1-eps)
y = np.clip(y, eps, 1.0 - eps)
df_kde['Median nRF (KDE)'] = y

# ---------- 5) Plot ----------
plt.figure(figsize=(max(10, 0.6*len(order)), 5))
sns.violinplot(
    data=df_kde[df_kde['Group'].isin(order)],
    x='Group', y='Median nRF (KDE)',
    order=order, palette=palette,
    cut=0,            # no extension below min / above max
    bw_adjust=0.7,    # gentler bandwidth (tune 0.5–1.0)
    inner='quartile', # show median & IQR for orientation
    linewidth=0.8
)

# axis from real data (not jittered)
ymax = df_plot.loc[df_plot['Group'].isin(order), 'Median nRF'].max()
plt.ylim(0, ymax * 1.10 if np.isfinite(ymax) else None)
plt.xticks(rotation=30, ha='right')
plt.ylabel('Median Normalised RF')
plt.xlabel('')
plt.title('Median Normalised Robinson-Foulds Distance -- All Models for seed-alignment dataset')
plt.tight_layout()
plt.show()

# Optional: quick summaries from real data
print('Group medians:')
print(df_plot.groupby('Group')['Median nRF'].median().reindex(order).round(4))
print('\nGroup means:')
print(df_plot.groupby('Group')['Median nRF'].mean().reindex(order).round(4))
# Out:
# /var/folders/7l/28yzqfm93j105y85x5rns4bryc93vy/T/ipykernel_7361/2269017078.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# Group medians:
# Group
# DNA vs DNA           0.0465
# DNA vs RNA (S16)     0.2667
# DNA vs RNA (S16A)    0.2222
# DNA vs RNA (S16B)    0.2727
# DNA vs RNA (S7A)     0.2500
# DNA vs RNA (S7B)     0.2500
# DNA vs RNA (S7C)     0.2353
# DNA vs RNA (S7D)     0.2222
# DNA vs RNA (S7E)     0.2240
# DNA vs RNA (S7F)     0.2143
# DNA vs RNA (S6A)     0.2727
# DNA vs RNA (S6B)     0.2500
# DNA vs RNA (S6C)     0.2500
# DNA vs RNA (S6D)     0.2500
# DNA vs RNA (S6E)     0.2500
# Name: Median nRF, dtype: float64
#
# Group means:
# Group
# DNA vs DNA           0.1653
# DNA vs RNA (S16)     0.2975
# DNA vs RNA (S16A)    0.2681
# DNA vs RNA (S16B)    0.3018
# DNA vs RNA (S7A)     0.2847
# DNA vs RNA (S7B)     0.2792
# DNA vs RNA (S7C)     0.2788
# DNA vs RNA (S7D)     0.2716
# DNA vs RNA (S7E)     0.2740
# DNA vs RNA (S7F)     0.2689
# DNA vs RNA (S6A)     0.3078
# DNA vs RNA (S6B)     0.3006
# DNA vs RNA (S6C)     0.2991
# DNA vs RNA (S6D)     0.2994
# DNA vs RNA (S6E)     0.3016
# Name: Median nRF, dtype: float64

# %%
plt.figure(figsize=(max(10, 0.6*len(order)), 5))
sns.boxenplot(data=df_plot[df_plot['Group'].isin(order)],
              x='Group', y='Median nRF', order=order, color='white', showfliers=False)
sns.stripplot(data=df_plot[df_plot['Group'].isin(order)],
              x='Group', y='Median nRF', order=order, size=1.5, alpha=0.25, color='k')
plt.ylim(0, ymax * 1.10 if np.isfinite(ymax) else None)
plt.xticks(rotation=30, ha='right')
plt.title('Median Normalised RF of seed-alignment data: DNA vs DNA and DNA vs RNA (all models)')
plt.tight_layout(); plt.show()

# %%
plt.figure(figsize=(max(10, 0.6*len(order)), 5))
sns.boxenplot(data=df_plot[df_plot['Group'].isin(order)],
              x='Group', y='Median nRF', order=order,
              palette=palette, showfliers=False)
sns.stripplot(data=df_plot[df_plot['Group'].isin(order)],
              x='Group', y='Median nRF', order=order,
              color='k', size=1.5, alpha=0.15, jitter=0.2)
plt.ylim(0, df_plot['Median nRF'].max()*1.1)
plt.xticks(rotation=30, ha='right')
plt.ylabel('Median Normalised RF'); plt.xlabel('')
plt.title('Median Normalised RF: DNA vs DNA and DNA vs RNA (all models)')
plt.tight_layout(); plt.show()
# Out:
# /var/folders/7l/28yzqfm93j105y85x5rns4bryc93vy/T/ipykernel_7361/3927777074.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(data=df_plot[df_plot['Group'].isin(order)],

# %% [markdown]
# ## 2. representative SEED

# %%
import re
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# -------- configuration --------------------------------------------------------
models_to_show = ['S16', 'S7A', 'S6A']
groups_order   = ['DNA vs DNA'] + [f'DNA vs RNA ({m})' for m in models_to_show]

# line-drawing rules
rel_threshold = 0.25   # 10% relative difference to draw a segment
round_ndec    = 3      # treat values equal if equal after rounding to 3 dp

# colors
palette = {
    'DNA vs DNA': '#d3d3d3',             # light gray
    'DNA vs RNA (S16)':  sns.color_palette('Oranges', 3)[1],
    'DNA vs RNA (S7A)':  sns.color_palette('Blues',   5)[2],
    'DNA vs RNA (S6A)':  sns.color_palette('Greens',  5)[2],
}

# -------- build plotting table without mutating df_medians ---------------------
# baseline from DNA_extra → rename to "DNA vs DNA"
base_mask = (seed_medians['Model']=='DNA_extra') & (seed_medians['Category']=='DNA vs extra DNA')
df_base = (
    seed_medians.loc[base_mask, ['RNA','Median nRF']].copy()
              .assign(Group='DNA vs DNA')
)

# S-model rows we care about
df_models = seed_medians[
    (seed_medians['Model'].isin(models_to_show)) &
    (seed_medians['Category'].str.startswith('DNA vs RNA'))
].copy()

# ensure group label is "DNA vs RNA (MODEL)"
def ensure_group(row):
    cat = str(row['Category'])
    if '(' in cat and ')' in cat:
        return cat
    return f"DNA vs RNA ({row['Model']})"

df_models['Group'] = df_models.apply(ensure_group, axis=1)

# combine
df_long = pd.concat(
    [df_base[['RNA','Group','Median nRF']], df_models[['RNA','Group','Median nRF']]],
    ignore_index=True
).dropna(subset=['Median nRF'])

# pivot to wide so each RNA has four columns in the desired order
df_wide = (
    df_long.pivot(index='RNA', columns='Group', values='Median nRF')
           .reindex(columns=groups_order)
           .dropna(how='any')   # keep RNAs present in all 4 groups
)

# -------- plot: violins + conditional connecting lines ------------------------
plt.figure(figsize=(9, 6))

# violins
sns.violinplot(
    data=df_long[df_long['Group'].isin(groups_order)],
    x='Group', y='Median nRF',
    order=groups_order,
    palette=palette,
    cut=0,        # no extension below min (keeps bottom at 0)
    inner=None,
    linewidth=0.8
)

# cosmetics
ymax = df_long['Median nRF'].max()
plt.ylim(0, ymax*1.1 if np.isfinite(ymax) else None)
#plt.xticks(ticks=xpos, labels=groups_order, rotation=25, ha='right')
plt.ylabel('Median Normalised RF')
plt.title(f'Medinan Normalised Robinson-Foulds Distance -- Model S16, S7A, S6A for seed-alignment dataset')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/7l/28yzqfm93j105y85x5rns4bryc93vy/T/ipykernel_7361/134943509.py:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /var/folders/7l/28yzqfm93j105y85x5rns4bryc93vy/T/ipykernel_7361/134943509.py:79: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import re
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# -------- configuration --------------------------------------------------------
models_to_show = ['S16', 'S7A', 'S6A']
groups_order   = ['DNA vs DNA'] + [f'DNA vs RNA ({m})' for m in models_to_show]

# line-drawing rules
rel_threshold = 0.25   # 10% relative difference to draw a segment
round_ndec    = 3      # treat values equal if equal after rounding to 3 dp

# colors
palette = {
    'DNA vs DNA': '#d3d3d3',             # light gray
    'DNA vs RNA (S16)':  sns.color_palette('Oranges', 3)[1],
    'DNA vs RNA (S7A)':  sns.color_palette('Blues',   5)[2],
    'DNA vs RNA (S6A)':  sns.color_palette('Greens',  5)[2],
}

# -------- build plotting table without mutating df_medians ---------------------
# baseline from DNA_extra → rename to "DNA vs DNA"
base_mask = (seed_medians['Model']=='DNA_extra') & (seed_medians['Category']=='DNA vs extra DNA')
df_base = (
    seed_medians.loc[base_mask, ['RNA','Median nRF']].copy()
              .assign(Group='DNA vs DNA')
)

# S-model rows we care about
df_models = seed_medians[
    (seed_medians['Model'].isin(models_to_show)) &
    (seed_medians['Category'].str.startswith('DNA vs RNA'))
].copy()

# ensure group label is "DNA vs RNA (MODEL)"
def ensure_group(row):
    cat = str(row['Category'])
    if '(' in cat and ')' in cat:
        return cat
    return f"DNA vs RNA ({row['Model']})"

df_models['Group'] = df_models.apply(ensure_group, axis=1)

# combine
df_long = pd.concat(
    [df_base[['RNA','Group','Median nRF']], df_models[['RNA','Group','Median nRF']]],
    ignore_index=True
).dropna(subset=['Median nRF'])

# pivot to wide so each RNA has four columns in the desired order
df_wide = (
    df_long.pivot(index='RNA', columns='Group', values='Median nRF')
           .reindex(columns=groups_order)
           .dropna(how='any')   # keep RNAs present in all 4 groups
)

# -------- plot: violins + conditional connecting lines ------------------------
plt.figure(figsize=(9, 6))

# violins
sns.violinplot(
    data=df_long[df_long['Group'].isin(groups_order)],
    x='Group', y='Median nRF',
    order=groups_order,
    palette=palette,
    cut=0,        # no extension below min (keeps bottom at 0)
    inner=None,
    linewidth=0.8
)

# spaghetti lines per RNA, only when adjacent groups differ by ≥10%
xpos = np.arange(len(groups_order))
for rna, row in df_wide.iterrows():
    vals = row.values.astype(float)

    # draw per adjacent pair (0->1, 1->2, 2->3)
    for i in range(len(vals)-1):
        v1, v2 = vals[i], vals[i+1]

        # skip if equal after rounding
        if round(v1, round_ndec) == round(v2, round_ndec):
            continue

        # compute relative difference
        if v1 == 0 and v2 == 0:
            continue
        if v1 == 0 or v2 == 0:
            rel_diff = max(v1, v2)  # if one is zero, treat diff as the other value
        else:
            rel_diff = abs(v2 - v1) / min(v1, v2)

        if rel_diff >= rel_threshold:
            plt.plot([xpos[i], xpos[i+1]], [v1, v2],
                     color='k', alpha=0.08, linewidth=0.6)

# median trend (optional)
med = df_wide.median(axis=0)
plt.plot(xpos, med.values, color='black', linewidth=2)

# cosmetics
ymax = df_long['Median nRF'].max()
plt.ylim(0, ymax*1.1 if np.isfinite(ymax) else None)
plt.xticks(ticks=xpos, labels=groups_order, rotation=25, ha='right')
plt.ylabel('Median Normalised RF')
plt.title(f'Median Normalised RF: DNA vs DNA ↔ DNA vs RNA: S16 → S7A → S6A (lines ≥{rel_threshold*100}% change)')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/7l/28yzqfm93j105y85x5rns4bryc93vy/T/ipykernel_7361/1680056875.py:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /var/folders/7l/28yzqfm93j105y85x5rns4bryc93vy/T/ipykernel_7361/1680056875.py:108: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /var/folders/7l/28yzqfm93j105y85x5rns4bryc93vy/T/ipykernel_7361/1680056875.py:108: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#!/usr/bin/env python3
"""
Violin plot: DNA_extra vs S16, S7A, S6A with connecting lines
Connecting lines show median nRF for the same RNAs across groups
Lines only visible when difference between adjacent groups >= 25%
"""

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# ─── 1) FILTER DATA FOR SELECTED COMPARISONS ───────────────────────────────────
comparisons_to_show = ['DNA vs DNA_extra', 'DNA vs S16', 'DNA vs S7A', 'DNA vs S6A']
groups_order = comparisons_to_show

# Extract data for selected comparisons
df_filtered = seed_medians[seed_medians['Comparison'].isin(comparisons_to_show)].copy()

if len(df_filtered) == 0:
    print("✗ ERROR: No data found for selected comparisons")
else:
    # ─── 2) PIVOT TO WIDE FORMAT FOR CONNECTING LINES ──────────────────────────
    df_wide = df_filtered.pivot(index='RNA', columns='Comparison', values='Median nRF')
    df_wide = df_wide.reindex(columns=groups_order)
    df_wide_complete = df_wide.dropna(how='any')  # keep only RNAs with all 4 groups
    
    # ─── 3) COLOR PALETTE ────────────────────────────────────────────────────────
    palette = {
        'DNA vs DNA_extra': '#606060',  # dark gray
        'DNA vs S16': '#FF9500',        # orange
        'DNA vs S7A': '#1F77B4',        # blue
        'DNA vs S6A': '#2CA02C'         # green
    }
    
    # ─── 4) PLOT: VIOLIN + CONNECTING LINES ──────────────────────────────────────
    plt.figure(figsize=(10, 6))
    
    # Violin plot
    sns.violinplot(
        data=df_filtered,
        x='Comparison',
        y='Median nRF',
        order=groups_order,
        palette=palette,
        cut=0,
        inner='box',  # show median & quartiles
        linewidth=1.0
    )
    
    # Add connecting lines for RNAs with ≥25% difference
    xpos = np.arange(len(groups_order))
    threshold = 0.25  # 25% relative difference threshold
    
    for rna, row in df_wide_complete.iterrows():
        vals = row.values.astype(float)
        
        # Draw lines between adjacent groups
        for i in range(len(vals) - 1):
            v1, v2 = vals[i], vals[i+1]
            
            # Skip if both are NaN
            if np.isnan(v1) or np.isnan(v2):
                continue
            
            # Calculate relative difference
            if v1 == 0 and v2 == 0:
                rel_diff = 0
            elif v1 == 0 or v2 == 0:
                rel_diff = max(abs(v1), abs(v2))  # use absolute value if one is zero
            else:
                rel_diff = abs(v2 - v1) / min(abs(v1), abs(v2))
            
            # Draw line only if difference >= 25%
            if rel_diff >= threshold:
                plt.plot([xpos[i], xpos[i+1]], [v1, v2],
                        color='black', alpha=0.10, linewidth=0.8, zorder=1)
    
    # ─── 5) LABELS & FORMATTING ─────────────────────────────────────────────────
    ymax = df_filtered['Median nRF'].max()
    plt.ylim(0, ymax * 1.15)
    
    plt.xlabel('Comparison Group', fontsize=11, fontweight='bold')
    plt.ylabel('Median Normalised RF Distance', fontsize=11, fontweight='bold')
    plt.title(f'Median Normalised RF: DNA_extra vs S16, S7A, S6A\n(Lines shown for ≥{threshold*100}% difference)', 
              fontsize=12, fontweight='bold', pad=15)
    plt.xticks(rotation=15, ha='right')
    plt.grid(axis='y', alpha=0.3, linestyle='--')
    plt.tight_layout()
    plt.show()
    
    # ─── 6) SUMMARY STATISTICS ──────────────────────────────────────────────────
    print("\n" + "="*70)
    print("SUMMARY: Median Normalised RF Distances (Selected Models)")
    print("="*70)
    print(f"RNAs with complete data across all 4 groups: {len(df_wide_complete)}")
    print("\nMedian nRF per Comparison Group:")
    print("-"*70)
    
    for comp in groups_order:
        data = df_filtered[df_filtered['Comparison'] == comp]['Median nRF']
        print(f"{comp:25} | N={len(data):3} | Median={data.median():.4f} | Mean={data.mean():.4f} | Std={data.std():.4f}")
    
    print("="*70)
# Out:
# /var/folders/7l/28yzqfm93j105y85x5rns4bryc93vy/T/ipykernel_7361/1790438756.py:40: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# ======================================================================
# SUMMARY: Median Normalised RF Distances (Selected Models)
# ======================================================================
# RNAs with complete data across all 4 groups: 1788
#
# Median nRF per Comparison Group:
# ----------------------------------------------------------------------
# DNA vs DNA_extra          | N=2260 | Median=0.0465 | Mean=0.1653 | Std=0.2203
# DNA vs S16                | N=1788 | Median=0.2667 | Mean=0.2975 | Std=0.2889
# DNA vs S7A                | N=1788 | Median=0.2500 | Mean=0.2847 | Std=0.2876
# DNA vs S6A                | N=1788 | Median=0.2727 | Mean=0.3078 | Std=0.3011
# ======================================================================
